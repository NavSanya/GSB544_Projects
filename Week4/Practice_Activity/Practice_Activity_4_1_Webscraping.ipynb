# %% [raw]
# ---
# title: Practice 4.1
# author: Nav Sanya Anand
# format:
#         html:
#                 toc: true
#                 code-fold: true
#                 embed-resources: true
# theme: sketchy
#
# ---

# %% [markdown]
# # XML, HTML, and Web Scraping
#
# JSON and XML are two different ways to represent hierarchical data. Which one is better? There are lots of articles online which discuss similarities and differences between JSON and XML and their advantages and disadvantages. Both formats are still in current usage, so it is good to be familiar with both. However, JSON is more common, so we'll focus on working with JSON representations of hierarchical data.
#
# The reading covered an example of using Beautiful Soup to parse XML. Rather than doing another example XML now, we'll skip straight to scraping HTML from a webpage. Both HTML and XML can be parsed in a similar way with Beautiful Soup.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from pprint import pprint

# %%
# df_cities2 = pd.read_html("https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population", attrs = {'class': 'wikitable sortable', "style": "text-align:center"})[0]
# df_cities2

# %%
response = requests.get("https://statistics.calpoly.edu/content/directory")

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
pprint(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head profile="http://www.w3.org/1999/xhtml/vocab">
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"4e34bbaf17",applicationID:"4513637"};;/*! For license information please see nr-loader-rum-1.299.0.min.js.LICENSE.txt */
# (()=>{var e,t,r={122:(e,t,r)=>{"use strict";r.d(t,{a:()=>i});var n=r(944);function i(e,t){try{if(!e||"object"!=typeof e)return(0,n.R)(3);if(!t||"object"!=typeof t)return(0,n.R)(4);const r=Object.create(Object.getPrototypeOf(t),Object.getOwnPropertyDescriptors(t)),a=0===Object.keys(r).length?e:r;for(let s in a)if(void 0!==e[s])try{if(null===e[s]){r[s]=null;continue}Array.isArray(e[s])&&Array.isArray(t[s])?r[s]=Array.from(new Set([...e[s],...t[s]])):"object"==typeof e[s]&&"object"==typeof t[s]?r[s]=i(e[s],t[s]):r[s]=e[s]}catch(e){r[s]||(0,n.R)(1,e)}return r}catch(e){(0,n.R)(2,e)}}},555:(e,t,r)=>{"use strict";r.d(t,{D:()=>o,f:()=>s});var n=r(384),i=r(122);const a={beacon:n.NT.beacon,errorBeacon:n.NT.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0};function s(e){try{return!!e.licenseKey&&!!e.errorBeacon&&!!e.applicationID}catch(e){return!1}}const o=e=>(0,i.a)(e,a)},699:(e,t,r)=>{"use strict";r.d(t,{It:()=>i,No:()=>n,qh:()=>s,uh:()=>a});const n=16e3,i=1e6,a="NR_CONTAINER_AGENT",s="SESSION_ERROR"},324:(e,t,r)=>{"use strict";r.d(t,{F3:()=>i,Xs:()=>a,xv:()=>n});const n="1.299.0",i="PROD",a="CDN"},154:(e,t,r)=>{"use strict";r.d(t,{OF:()=>c,RI:()=>i,WN:()=>d,bv:()=>a,gm:()=>s,mw:()=>o,sb:()=>u});var n=r(863);const i="undefined"!=typeof window&&!!window.document,a="undefined"!=typeof WorkerGlobalScope&&("undefined"!=typeof self&&self instanceof WorkerGlobalScope&&self.navigator instanceof WorkerNavigator||"undefined"!=typeof globalThis&&globalThis instanceof WorkerGlobalScope&&globalThis.navigator instanceof WorkerNavigator),s=i?window:"undefined"!=typeof WorkerGlobalScope&&("undefined"!=typeof self&&self instanceof WorkerGlobalScope&&self||"undefined"!=typeof globalThis&&globalThis instanceof WorkerGlobalScope&&globalThis),o=Boolean("hidden"===s?.document?.visibilityState),c=/iPad|iPhone|iPod/.test(s.navigator?.userAgent),u=c&&"undefined"==typeof SharedWorker,d=((()=>{const e=s.navigator?.userAgent?.match(/Firefox[/\s](\d+\.\d+)/);Array.isArray(e)&&e.length>=2&&e[1]})(),Date.now()-(0,n.t)())},241:(e,t,r)=>{"use strict";r.d(t,{W:()=>a});var n=r(154);const i="newrelic";function a(e={}){try{n.gm.dispatchEvent(new CustomEvent(i,{detail:e}))}catch(e){}}},687:(e,t,r)=>{"use strict";r.d(t,{Ak:()=>u,Ze:()=>f,x3:()=>d});var n=r(241),i=r(836),a=r(606),s=r(860),o=r(646);const c={};function u(e,t){const r={staged:!1,priority:s.P3[t]||0};l(e),c[e].get(t)||c[e].set(t,r)}function d(e,t){e&&c[e]&&(c[e].get(t)&&c[e].delete(t),p(e,t,!1),c[e].size&&g(e))}function l(e){if(!e)throw new Error("agentIdentifier required");c[e]||(c[e]=new Map)}function f(e="",t="feature",r=!1){if(l(e),!e||!c[e].get(t)||r)return p(e,t);c[e].get(t).staged=!0,g(e)}function g(e){const t=Array.from(c[e]);t.every((([e,t])=>t.staged))&&(t.sort(((e,t)=>e[1].priority-t[1].priority)),t.forEach((([t])=>{c[e].delete(t),p(e,t)})))}function p(e,t,r=!0){const s=e?i.ee.get(e):i.ee,c=a.i.handlers;if(!s.aborted&&s.backlog&&c){if((0,n.W)({agentIdentifier:e,type:"lifecycle",name:"drain",feature:t}),r){const e=s.backlog[t],r=c[t];if(r){for(let t=0;e&&t<e.length;++t)m(e[t],r);Object.entries(r).forEach((([e,t])=>{Object.values(t||{}).forEach((t=>{t[0]?.on&&t[0]?.context()instanceof o.y&&t[0].on(e,t[1])}))}))}}s.isolatedBacklog||delete c[t],s.backlog[t]=null,s.emit("drain-"+t,[])}}function m(e,t){var r=e[1];Object.values(t[r]||{}).forEach((t=>{var r=e[0];if(t[0]===r){var n=t[1],i=e[3],a=e[2];n.apply(i,a)}}))}},836:(e,t,r)=>{"use strict";r.d(t,{P:()=>o,ee:()=>c});var n=r(384),i=r(990),a=r(646),s=r(607);const o="nr@context:".concat(s.W),c=function e(t,r){var n={},s={},d={},l=!1;try{l=16===r.length&&u.initializedAgents?.[r]?.runtime.isolatedBacklog}catch(e){}var f={on:p,addEventListener:p,removeEventListener:function(e,t){var r=n[e];if(!r)return;for(var i=0;i<r.length;i++)r[i]===t&&r.splice(i,1) ...
# <link href="https://statistics.calpoly.edu/sites/all/themes/cpstandard_r/common/images_html/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <meta content="en" http-equiv="content-language"/>
# <meta charset="utf-8"/>
# <meta content="initial-scale=1" name="viewport"/>
# <meta content="Statistics Department California Polytechnic State University Building 25, Room 107D San Luis Obispo, CA 93407-0405 Telephone: (805) 756-2709 Email: statisticsdepartment@calpoly.edu Fall 2025 Office Hours Office hours for each instructor have been posted below. For additional information, please review your course syllabus and/or visit your course's Canvas page.  Name Office" name="description"/>
# <link href="https://statistics.calpoly.edu/content/directory" rel="canonical"/>
# <meta content="Statistics Department" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="https://statistics.calpoly.edu/content/directory" property="og:url"/>
# <meta content="Directory &amp; Office Hours | Statistics Department" property="og:title"/>
# <meta content="Statistics Department California Polytechnic State University Building 25, Room 107D San Luis Obispo, CA 93407-0405 Telephone: (805) 756-2709 Email: statisticsdepartment@calpoly.edu Fall 2025 Office Hours Office hours for each instructor have been posted below. For additional information, please review your course syllabus and/or visit your course's Canvas page.  Name Office Phone (805) Email  Office Hours    Andrew Schaffner  (Chair and Professor of Statistics)  25-107C 756-1545 aschaffn@calpoly.edu  M 11:10-12pm  W 10:10-11am &amp; Zoom by appointment   Marieke Montenegro  (Administrative Support Coordinator)   25-107D  756-2709 mmonte19@calpoly.edu M-F 9am-12pm, 1-4pm Back to top Faculty  Name  Office Phone (805) Email  Office HoURS   Lubaba Alim 25-111 756-2792 lfalim@calpoly.edu MWF 10:10-11am Kelly Bodwin 25-106 756-2450 kbodwin@calpoly.edu  TR 3:10-5pm  Matt Carlton 25-101 756-7076 mcarlton@calpoly.edu  T-F 4:30-5:30pm; only on Zoom (link in Canvas)   Beth Chance  Aprendiendo español  25-235  756-2961  bchance@calpoly.edu  MR 10-11am  W 10-12pm &amp; by appointment  Calendly     Nian Cheng 25-119 756-1825 ncheng@calpoly.edu  T 10:10-11am; 1-2pm  R 10:10-11am &amp; by appointment   Olga Dekhtyar  Я говорю по-русски.  25-130 756-6354 odekhtya@calpoly.edu  TW 10:20-11:20am  R 10:10-11:10am  F 10:10-11am      Sinem Demirci  Türkçe konuşuyorum  25-213 756-0683 sdemirci@calpoly.edu  M 11:10-12:50pm in person  W 2:10-3:50pm Zoom   
234 756-2941 srein@calpoly.edu     T 9-10am  R 10-11am &amp; by appointment  Calendly     Emily Robinson 25-103 756-2715 erobin17@calpoly.edu  MW 1:10-2:30pm  R 1:10-2pm  Kevin Ross 25-237 756-5739 kjross@calpoly.edu  M 10:10-11am  T 2:10-3pm  W 1:30-2:30pm  R 9:30-10:30am   Soma Roy  Languages spoken: English, हिन्दी, বাংলা  25-104  756-5250  soroy@calpoly.edu  W 10:10-11am; in person  F 11:10-12pm; Zoom   Trevor Ruiz  Se habla español  25-236 756-2776 truiz01@calpoly.edu  T-R 12-2pm  Calendly   Anelise Sabbag  Eu falo português!   25-222  756-5562  asabbag@calpoly.edu   MW 12:10-1pm; in person  TF 8:10-9am; Zoom (Link in Canvas)  Julia Schedler 25-212 756-5877 jschedle@calpoly.edu  TR 3:30-5pm  Maddie Schroth 25-223  756-6310  mschroth@calpoly.edu  MW 8:10-9am; Zoom  TR 12:10-1pm; in person  Sonja Schuster 25-119 756-1825 sschuste@calpoly.edu  W 4:10-5pm  R 11:10-12pm   only on Zoom  Jeffrey Sklar  25-110  756-6353 jsklar@calpoly.edu  MW 1:10-2pm  TR 10:10-11am  Heather Smith 25-112 756-6128 hsmith@calpoly.edu  TR 12:15-1pm  W 9:15-11am  Calendly &amp; by appointment  Allison Theobold 25-105 756-5529 atheobol@calpoly.edu MR 2:10-3pm John Walker 25-226 756-7128 jwalker@calpoly.edu  Contact Instructor  Yi-Hui Wang 25-119 756-1825 ywang59@calpoly.edu  W 10:30-11:30am; in person  F 9:10-10am; Zoom  Immanuel Williams 25-113 756-2709 imwillia@calpoly.edu T ...
# <meta content="Text" name="dcterms.type"/>
# <meta content="text/html" name="dcterms.format"/>
# <title>Directory &amp; Office Hours - Statistics Department - Cal Poly, San Luis Obispo</title>
# <style media="all" type="text/css">
# @import url("https://statistics.calpoly.edu/modules/system/system.base.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/modules/system/system.menus.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/modules/system/system.messages.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/modules/system/system.theme.css?t3rxwf");
# </style>
# <style media="all" type="text/css">
# @import url("https://statistics.calpoly.edu/modules/aggregator/aggregator.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/modules/comment/comment.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/modules/field/theme/field.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/modules/node/node.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/modules/search/search.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/modules/user/user.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/sites/all/modules/views/css/views.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/sites/all/modules/ckeditor/css/ckeditor.css?t3rxwf");
# </style>
# <style media="all" type="text/css">
# @import url("https://statistics.calpoly.edu/sites/all/modules/ctools/css/ctools.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/sites/all/modules/tableofcontents/tableofcontents.css?t3rxwf");
# </style>
# <link href="//fonts.googleapis.com/css?family=Open+Sans:400,600%7CVollkorn:400italic,400" media="all" rel="stylesheet" type="text/css"/>
# <style media="all" type="text/css">
# @import url("https://statistics.calpoly.edu/sites/all/themes/cpstandard_r/common/css/cp_style.min.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/sites/all/themes/cpstandard_r/common/css/font-awesome.min.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/sites/all/themes/cpstandard_r/common/css/jquery-ui.min.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/sites/all/themes/cpstandard_r/css/cp_custom.css?t3rxwf");
# @import url("https://statistics.calpoly.edu/sites/all/themes/cpstandard_r/css/honeypot.css?t3rxwf");
# </style>
# <style media="print" type="text/css">
# @import url("https://statistics.calpoly.edu/sites/all/themes/cpstandard_r/common/css/cp_print.min.css?t3rxwf");
# </style>
# <script src="https://statistics.calpoly.edu/sites/statistics.calpoly.edu/files/js/js_YD9ro0PAqY25gGWrTki6TjRUG8TdokmmxjfqpNNfzVU.js" type="text/javascript"></script>
# <script src="https://statistics.calpoly.edu/sites/statistics.calpoly.edu/files/js/js_-zpHfuGV_8VVwgRhy2PKeQaVJAtxKrM3J3ALmgmc1PQ.js" type="text/javascript"></script>
# <script src="https://statistics.calpoly.edu/sites/statistics.calpoly.edu/files/js/js_Koy9SwiUJmXG6zyo7C_1eqnqg3wjiLSjat9vhI0EoTw.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","setHasJsCookie":0,"ajaxPageState":{"theme":"cpstandard_r","theme_token":"EnXKRDqtIuPi8tnDklOh5xhwXwgfHpBS-jhKsJcrbL8","js":{"misc\/jquery.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/tableofcontents\/jquery.scrollTo-min.js":1,"sites\/all\/modules\/tableofcontents\/jquery.localscroll-min.js":1,"sites\/all\/modules\/tableofcontents\/tableofcontents.js":1,"sites\/all\/themes\/cpstandard_r\/common\/js\/jquery-1.11.3.min.js":1,"sites\/all\/themes\/cpstandard_r\/common\/js\/jquery-ui.min.js":1,"sites\/all\/themes\/cpstandard_r\/common\/js\/noconflict.js":1,"sites\/all\/themes\/cpstandard_r\/common\/js\/calpoly.min.js":1,"sites\/all\/themes\/cpstandard_r\/common\/js\/_accordion.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"modules\/aggregator\/aggregator.css":1,"modules\/comment\/comment.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/views\/css\/views.css":1,"sites\/all\/modules\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/modules\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/tableofcontents\/tableofcontents.css":1,"\/\/fonts.googleapis.com\/css?family=Open+Sans:400,600%7CVollkorn:400italic,400":1,"sites\/all\/themes\/cpstandard_r\/common\/css\/cp_style.min.css":1,"sites\/all\/themes\/cpstandard_r\/common\/css\/font-awesome.min.css":1,"sites\/all\/themes\/cpstandard_r\/common\/css\/jquery-ui.min.css":1,"sites\/all\/themes\/cpstandard_r\/css\/cp_custom.css":1,"sites\/all\/themes\/cpstandard_r\/css\/honeypot.css":1,"sites\/all\/themes\/cpstandard_r\/common\/css\/cp_print.min.css":1}},"tableOfContents":{"boxSettings":{"hideText":"hide","showText":"show"}}});
# //--><!]]>
# </script>
# <!-- Global Site Tag (gtag.js) - Google Analytics -->
# <!-- Google Analytics - contact Cal Poly University Marketing for access to GA data -->
# <!-- GTM / Contact UCM -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-TKZNRR2');</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-CY2GPTVZY7"></script>
# <script>window.dataLayer = window.dataLayer || []; function gtag() {window.dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'G-CY2GPTVZY7'); </script>
# <!-- End GA gtag -->
# <!-- Slate / Contact SEM -->
# <script async="async" src="https://connect.calpoly.edu/ping">/**/</script>
# <!-- End Slate -->
# </head>
# <body class="html not-front not-logged-in no-sidebars page-node page-node- page-node-158 node-type-page">
# <!--Header Content for Analytics-->
# <div class="region region-header-content" id="header-blocks">
# <div class="block block-block" id="block-block-7">
# <!-- Go to www.addthis.com/dashboard to customize your tools --><script async="async" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-559428594795f71a" type="text/javascript"></script><p><br/><!-- Add your analytics script here e.g. Google Analytics --><!-- If you don't want to use analytics, just ignore this block --></p></div>
# </div>
# <div id="wrapper">
# <header>
# <div id="accessibilityNav"><ul><li><a href="#topH1" id="skip" title="skip to content">Skip to Content</a></li><li><a href="https://www.calpoly.edu/help.html" id="helpLink" title="help">?</a></li></ul></div> <div id="audienceNav"><ul><li><a href="http://www.calpoly.edu/student/enrolled.html">Current Students</a></li>
# <li><a href="http://admissions.calpoly.edu/">Prospective Students</a></li>
# <li><a href="http://www.calpoly.edu/student/parents.html">Parents</a></li>
# <li><a href="http://www.calpoly.edu/business-community.html">Business Community</a></li>
# <li><a href="http://www.calpoly.edu/faculty-staff/faculty-staff.html">Faculty &amp; Staff</a></li>
# <li><a href="http://alumni.calpoly.edu/">Alumni</a></li>
# </ul></div> <hr/>
# <div id="myCalPolyNav"><a href="https://my.calpoly.edu" id="login" title="my CalPoly login">my CalPoly login</a></div> <div id="utilityNav"><ul><li id="quicklinks"><span class="nolink" tabindex="0" title="">Quick Links</span>
# <ul id="quicklinksdropdown"><li class="darkGreen"><a href="/content/tutoring" tabindex="1">Tutoring</a></li>
# <li class="darkGreen"><a href="/content/statclub" tabindex="1">Stat Club</a></li>
# <li class="lightGreen"><a href="/content/contact" tabindex="1">Contact Us</a></li>
# </ul></li>
# <li id="contact"><a href="http://statistics.calpoly.edu/content/contact" title="">Contact</a></li>
# <li id="searchli"><div id="search"><form action="https://www.calpoly.edu/search/?q=" method="get" title="Search Form">
# <div>
# <input alt="Search Text" id="searchField" maxlength="256" name="q" placeholder="Search" title="Search this site" type="text"/>
# <input alt="Go" id="searchSubmit" name="submit" src="/sites/all/themes/cpstandard_r/common/images_html/header/search-arrow.png" title="Submit Search Query" type="image"/>
# </div>
# </form></div></li></ul></div>
# <div id="headerContent">
# <div id="headerTop">
# <div id="cplogo">
# <a href="https://www.calpoly.edu/">
# <img alt="Cal Poly" src="/sites/all/themes/cpstandard_r/common/images_html/header/cplogo.svg" title="Go to Cal Poly Home"/>
# </a>
# </div>
# <div id="mobileNavDept">
# <div id="mobileIcons">
# </div>
# </div>
# </div>
# <div id="mobileNav">
# <ul id="mobileMenu" style="display: none;">
# </ul>
# <ul id="mobileSearch" style="display: none;"><li id="searchli"><div id="search"><form action="https://www.calpoly.edu/search/?q=" method="get" title="Search Form">
# <div>
# <input alt="Search Text" id="searchField" maxlength="256" name="q" placeholder="Search" title="Search this site" type="text"/>
# <input alt="Go" id="searchSubmit" name="submit" src="/sites/all/themes/cpstandard_r/common/images_html/header/search-arrow.png" title="Submit Search Query" type="image"/>
# </div>
# </form></div></li></ul>
# </div><!-- end #mobileNav -->
# <div id="headerBottom">
# <div id="deptName"><h2><a href="/">Statistics Department</a></h2><h3><a href="http://www.cosam.calpoly.edu/">Bailey College of Science and Mathematics</a></h3></div>
# </div>
# </div>
# </header>
# <nav>
# <ul class="cpStandardNav" id="cpUl"><li><a href="/">Home</a></li>
# <li><a href="/content/about%20the%20department">About the Department</a></li>
# <li><a href="/content/curriculum">Curriculum</a></li>
# <li><a href="/content/current-students">Current Students</a></li>
# <li><a href="/content/prospective-students">Prospective Students</a></li>
# <li><a href="https://statistics.calpoly.edu/content/directory">Directory &amp; Office Hours</a></li>
# <li><a href="https://cosam.calpoly.edu/giving/">Giving</a></li>
# </ul> </nav>
# <!-- Old Breadcrumb Processing -->
# <div id="breadcrumb"><a href="/">Home</a> : Directory</div>
# <div id="rightCol">
# <div class="block block-menu" id="block-menu-menu-about-us-menu">
# <h2>More About the Department</h2>
# <ul><li class="first leaf"><a href="/content/mission" title="mission statement page">Mission &amp; Objective</a></li>
# <li class="leaf"><a href="/content/brief-history-department-and-statistics-major" title="">Statistics Department History</a></li>
# <li class="leaf active-trail"><a class="active-trail active" href="/content/directory" title="Directory">Directory</a></li>
# <li class="leaf"><a href="https://statistics.calpoly.edu/content/consulting" title="Link to Consulting page">Consulting</a></li>
# <li class="leaf"><a href="https://statistics.calpoly.edu/news/newsletter-2025" title="Link to the most recent Statistics Department newsletter">Current Newsletter</a></li>
# <li class="last leaf"><a href="https://statistics.calpoly.edu/content/newsletter" title="Link to archived Statistics Department newsletters">Past Newsletters</a></li>
# </ul></div>
# <div class="block block-block" id="block-block-21">
# <p><a href="https://cosam.calpoly.edu/giving/"><img alt="" height="58" src="//content-calpoly-edu.s3.amazonaws.com/statistics/1/images/support_button-08.png" width="200"/></a></p></div>
# <div class="block block-menu" id="block-menu-menu-website-update">
# <h2>Website Update</h2>
# <ul><li class="first last leaf"><a href="https://forms.gle/LFpZ3KvQaKEHQno88" title="">Submit Update Request</a></li>
# </ul></div>
# </div>
# <main id="">
# <a id="topH1"></a>
# <div id="contentLine"></div>
# <!-- Old Page Title Processing
#               <h1 class="page-title"></h1>
#             -->
# <div id="mainLeftFull"><div id="contentHeader"><h1 class="page-title">Directory &amp; Office Hours</h1></div> <div class="block block-system" id="block-system-main">
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even" property="content:encoded"><div>Statistics Department</div>
# <div>California Polytechnic State University</div>
# <div>Building 25, Room 107D<br/>
# San Luis Obispo, CA 93407-0405<br/>
# Telephone: (805) 756-2709</div>
# <div>Email: <a href="mailto:statisticsdepartment@calpoly.edu">statisticsdepartment@calpoly.edu</a></div>
# <h2 id="Fall_2025Office_Hours">Fall 2025 Office Hours</h2>
# <p>Office hours for each instructor have been posted below. For additional information, please review your course syllabus and/or visit your course's Canvas page. </p>
# <table cellspacing="0" class="directory backwhite" summary="COSAM Dean's Office Staff" width="100%"><tbody><tr><th scope="col" width="18%">Name</th>
# <th scope="col" width="8%">Office</th>
# <th scope="col" width="10%">Phone <strong>(805)</strong></th>
# <th scope="col" width="20%">Email</th>
# <th scope="col" width="20%">
# <p><span>Office Hours </span></p>
# </th>
# </tr><tr><td>
# <p><a href="/Andrew-Schaffner"><strong>Andrew Schaffner</strong></a></p>
# <p>(Chair and Professor of Statistics)</p>
# </td>
# <td><a href="https://maps.calpoly.edu/">25-107C</a></td>
# <td>756-1545</td>
# <td><a href="mailto:aschaffn@calpoly.edu">aschaffn@calpoly.edu</a></td>
# <td>
# <p><strong>M 11:10-12pm</strong></p>
# <p><strong>W 10:10-11am </strong>&amp; Zoom by appointment</p>
# </td>
# </tr><tr><td>
# <p><strong>Marieke Montenegro</strong></p>
# <p>(Administrative Support Coordinator)</p>
# </td>
# <td>
# <p><a href="https://maps.calpoly.edu/">25-107D</a></p>
# </td>
# <td>756-2709</td>
# <td><a href="mailto:mmonte19@calpoly.edu">mmonte19@calpoly.edu</a></td>
# <td><strong>M-F</strong> 9am-12pm, 1-4pm</td>
# </tr></tbody></table><div class="clear">
# <p class="backtotop"><br/><a href="#topH1">Back to top</a></p>
# </div>
# <h4 id="Faculty" name="Faculty">Faculty</h4>
# <table cellspacing="0" class="directory backwhite" height="2667" summary="COSAM Dean's Office Staff" width="596"><tbody><tr><th scope="col" width="18%">
# <p>Name</p>
# </th>
# <th scope="col" width="8%">Office</th>
# <th scope="col" width="10%">Phone (805)</th>
# <th scope="col" width="20%">Email</th>
# <th scope="col" width="20%">
# <p>Office HoURS </p>
# </th>
# </tr><tr><td><strong>Lubaba Alim</strong></td>
# <td><a href="http://maps.calpoly.edu/">25-111</a></td>
# <td>756-2792</td>
# <
a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-226</a></td>
# <td>756-7128</td>
# <td><a href="mailto:jwalker@calpoly.edu">jwalker@calpoly.edu</a></td>
# <td>
# <p>Contact Instructor</p>
# </td>
# </tr><tr><td><strong>Yi-Hui Wang</strong></td>
# <td>25-119</td>
# <td>756-1825</td>
# <td><a href="mailto:ywang59@calpoly.edu">ywang59@calpoly.edu</a></td>
# <td>
# <p><strong>W </strong>10:30-11:30am; in person</p>
# <p><strong>F</strong> 9:10-10am; Zoom</p>
# </td>
# </tr><tr><td><a href="/Immanuel-Williams"><strong>Immanuel Williams</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-113</a></td>
# <td>756-2709</td>
# <td><a href="mailto:imwillia@calpoly.edu">imwillia@calpoly.edu</a></td>
# <td><strong>TR </strong>2-4pm</td>
# </tr><tr><td><strong><a href="https://statistics.calpoly.edu/deniz-yenigun">Deniz Yenigün</a></strong><br/>
# 			Türkçe konuşuyorum</td>
# <td><a href="https://maps.calpoly.edu/">25-129</a></td>
# <td>756-0895</td>
# <td><a href="mailto:dyenigun@calpoly.edu">dyenigun@calpoly.edu</a></td>
# <td>
# <p>N/A</p>
# </td>
# </tr></tbody></table><div class="clear">
# <p class="backtotop"><br/><a href="#topH1">Back to top</a></p>
# </div>
# <h4 id="Emeritus_Faculty">Emeritus Faculty</h4>
# <table cellspacing="0" class="table_directory" summary="Emeritus Faculty"><thead><tr><th scope="col">Name</th>
# <th scope="col">Email</th>
# </tr></thead><tbody><tr><td><a href="https://statistics.calpoly.edu/allan-rossman" target="_blank"><strong>Allan Rossman</strong></a></td>
# <td><a href="mailto:arossman@calpoly.edu">arossman@calpoly.edu</a></td>
# </tr><tr><td><strong>Jay Devore</strong></td>
# <td>j<a href="mailto:devore@calpoly.edu">devore</a><a href="mailto:devore@calpoly.edu">@calpoly.edu</a></td>
# </tr><tr><td><strong>John Groves</strong></td>
# <td><a href="mailto:jgroves@calpoly.edu">jgroves@calpoly.edu</a></td>
# </tr><tr><td><strong>Roxy Peck</strong></td>
# <td><a href="mailto:rpeck@calpoly.edu">rpeck@calpoly.edu</a></td>
# </tr><tr><td><a href="https://statistics.calpoly.edu/robert-smidt" target="_blank"><strong>Bob Smidt</strong></a></td>
# <td><a href="mailto:rsmidt@calpoly.edu">rsmidt@calpoly.edu</a></td>
# </tr></tbody></table><!--break--></div></div></div></div>
# <h2 id="relatedLinksTitle">Related Content</h2><div id="relatedLinksBottom"></div></div>
# <div class="clear"></div>
# </main>
# <div class="clear"></div>
# <section class="widgets"> <div class="widget">
# <h2>Faculty Resources</h2>
# <p><a href="https://forms.office.com/Pages/ResponsePage.aspx?id=2wING578lUSVNx03nMoq516rwXvgws9HvyZuwQuxUkpUNk9HVjBMS1BJV1ZCNjg1QTNVWk9PSkpPVy4u">Faculty Issued Permissions</a></p>
# <p><a href="https://forms.office.com/r/90w7cbXtcZ">Common Final Request</a></p>
# <p><a href="https://forms.gle/kQamLaEh3Kthowb87">Alternate Final/Event Request</a></p>
# <p><a href="https://cosam.calpoly.edu/support/cosam_docs">BCSM Documents</a></p> </div>
# <div class="widget">
# <h2>DEI in the Bailey College</h2>
# <p><img alt="" height="176" src="https://content-calpoly-edu.s3.amazonaws.com/cosam/1/widget_images/CSM-IDEAS-DEI-widget-thumb-450_0.png" width="176"/></p>
-- Go to www.addthis.com/dashboard to customize your tools -->
# <script async="async" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-555cc8b26568eb20" type="text/javascript"></script><p><script type="text/javascript">
# <!--//--><![CDATA[// ><!--
#
#
#  var _gaq = _gaq || [];
#  _gaq.push(['_setAccount', 'UA-21462253-5']);
#  _gaq.push(['_trackPageview']);
#
#  (function() {
#    var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#    ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#    var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#  })();
#
#
# //--><!]]>
# </script></p></div>
# <div class="block block-block" id="block-block-8">
# <p><br><!-- Add your analytics script here e.g. CrazyEgg --><!-- If you don't want to use analytics, just ignore this block --></br></p></div>
# </div>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"4e34bbaf17","applicationID":"4513637","transactionName":"YldTYBRYXUVVURdZXFsdZEYPFlpYUFcbHkNdQg==","queueTime":0,"applicationTime":25,"atts":"ThBQFlxCTks=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>
# <script>(function trackOutbounds(){var hitCallbackHandler=function(url,win){if(win){window.open(url,win)}else{window.location.href=url}};var addEvent=function(el,eventName,handler){if(el.addEventListener){el.addEventListener(eventName,handler)}else{el.attachEvent('on'+eventName,function(){handler.call(el)})}}
# if(document.getElementsByTagName){var el=document.getElementsByTagName('a');var getDomain=document.domain.split('.').reverse()[1]+'.'+document.domain.split('.').reverse()[0];for(var i=0;i<el.length;i++){var href=(typeof(el[i].getAttribute('href'))=='string')?el[i].getAttribute('href'):'';var myDomain=href.match(getDomain);if((href.match(/^(https?:|\/\/)/i)&&!myDomain)||href.match(/^mailto\:/i)){addEvent(el[i],'click',function(e){var url=this.getAttribute('href'),win=(typeof(this.getAttribute('target'))=='string')?this.getAttribute('target'):'';console.log("add event",url);ga('send','event','outbound','click',url,{'hitCallback':hitCallbackHandler(url,win)},{'nonInteraction':1});e.preventDefault()})}}}})();</script>
# </html>

# %%
url = "https://tasty.p.rapidapi.com/recipes/list"

querystring = {"from":"0","size":"20","q":"daikon"}

headers = {
    "X-RapidAPI-Key": "57da288027msh4794f82bf9afd3ep1cc287jsnda6d9a2401dd",
    "X-RapidAPI-Host": "tasty.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

pprint(response.json())
# Out:
# {'count': 14,
#  'results': [{'approved_at': 1561944458,
#               'aspect_ratio': '1:1',
#               'beauty_url': 'https://img.buzzfeed.com/video-api-prod/assets/24657514c92f4d419e78747e777b1742/beauty.jpg',
#               'brand': None,
#               'brand_id': None,
#               'buzz_id': None,
#               'canonical_id': 'recipe:4326',
#               'compilations': [],
#               'cook_time_minutes': 90,
#               'country': 'US',
#               'created_at': 1535389545,
#               'credits': [{'is_verified': False,
#                            'name': "Merle O'Neal",
#                            'picture_url': '',
#                            'type': 'internal',
#                            'user_id': None}],
#               'description': 'Warm up your soul with this aromatic Vegan Pho, '
#                              'a delightful twist on the classic Vietnamese '
#                              'noodle soup. Packed with flavorful spices and '
#                              'fresh veggies, this comforting dish will leave '
#                              'you craving more!',
#               'draft_status': 'published',
#               'facebook_posts': [],
#               'id': 4326,
#               'inspired_by_url': 'https://www.connoisseurusveg.com/easy-vegan-pho/',
#               'instructions': [{'appliance': None,
#                                 'display_text': 'Add the dried shiitake '
#                                                 'mushrooms to a medium bowl '
#                                                 'and pour in enough water to '
#                                                 'cover. Cover with a dish '
#                                                 'towel and let hydrate for 8 '
#                                                 'hours, then rinse and drain '
#                                                 'the mushrooms 2-3 times. Set '
#                                                 'aside.',
#                                 'end_time': 8833,
#                                 'id': 38684,
#                                 'position': 1,
#                                 'start_time': 0,
#                                 'temperature': None},
#                                {'appliance': None,
#                                 'display_text': 'In a large pan over medium '
#                                                 'heat, dry sear the onions '
#                                                 'until caramelized on both '
#                                                 'sides, 10-15 minutes. '
#                                                 'Transfer to a bowl and repeat '
#                                                 'with the daikon radish and '
#                                                 'ginger. Set aside.',
#                                 'end_time': 46500,
#                                 'id': 38685,
#                                 'position': 2,
#                                 'start_time': 10666,
#                                 'temperature': None},
#                                {'appliance': None,
#                                 'display_text': 'Heat the oil in the pan. Add '
#                                                 'the oyster mushrooms and '
#                                                 'sauté until browned and '
#                                                 'caramelized, 6-8 minutes.',
#                                 'end_time': 54833,
#                                 'hacks': [{'end_index': 72,
#                                            'id': 13,
#                                            'match': 'browned',
#                                            'start_index': 66}],
#                                 'id': 38686,
#                                 'position': 3,
#                                 'start_time': 47000,
#                                 'temperature': None},
#                                {'appliance': None,
#                                 'display_text': 'Add the caramelized onions, '
#                                                 'daikon, ginger, oyster '
#                                                 'mushrooms, and soaked '
#                                                 'shiitake mushrooms to a large '
#                                                 'stock pot. Add the water and '
#                                                 'bring to a boil over high '
#                                                 'heat. Reduce the heat to low '
#                                                 'heat and cover. Simmer for at '
#                                                 'least 1 hour, or up to 8 '
#                                                 'hours. The longer it cooks, '
#                                                 'the stronger the flavor of '
#                                                 'the broth will be. Season '
#                                                 'with salt to taste.',
#                                 'end_time': 82833,
#                                 'hacks': [{'end_index': 146,
#                                            'id': 18,
#                                            'match': 'boil',
#                                            'start_index': 143}],
#                                 'id': 38687,
#                                 'position': 4,
#                                 'start_time': 61000,
#                                 'temperature': None},
#                                {'appliance': None,
#                                 'display_text': 'About 30 minutes before '
#                                                 'serving, combine the cinnamon '
#                                                 'stick, cloves, cardamom, star '
#                                                 'anise, coriander, and fennel '
#                                                 'in a fine-mesh sieve. Lower '
#                                                 'into the pot, resting the '
#                                                 'sieve on the edge, then cover '
#                                                 'and simmer for 15 minutes.',
#                                 'end_time': 99500,
#                                 'hacks': [{'end_index': 206,
#                                            'id': 17,
#                                            'match': 'simmer',
#                                            'start_index': 201}],
#                                 'id': 38688,
#                                 'position': 5,
#                                 'start_time': 86000,
#                                 'temperature': None},
#                                {'appliance': None,
#                                 'display_text': 'Remove the spices and add the '
#                                                 'tofu to heat through, 10-15 '
#                                                 'minutes.',
#                                 'end_time': 0,
#                                 'id': 38689,
#                                 'position': 6,
#                                 'start_time': 0,
#                                 'temperature': None},
#                                {'appliance': None,
#                                 'display_text': 'Remove the pot from the heat. '
#                                                 'Remove the onions, daikon, '
#                                                 'and ginger from the pot. '
#                                                 '(Slice and add them back to '
#                                                 'the soup, if desired.)',
#                                 'end_time': 0,
#                                 'id': 38690,
#                                 'position': 7,
#                                 'start_time': 0,
#                                 'temperature': None},
#                                {'appliance': None,
#                                 'display_text': 'Add the noodles to serving '
#                                                 'bowls and ladle in the broth, '
#                                                 'mushrooms, and tofu.',
#                                 'end_time': 140000,
#                                 'id': 38691,
#                                 'position': 8,
#                                 'start_time': 123666,
#                                 'temperature': None},
#                                {'appliance': None,
#                                 'display_text': 'Garnish with red onion, bean '
#                                                 'sprouts, chile peppers, a '
#                                                 'squeeze of lime, and '
#                                                 'cilantro.',
#                                 'end_time': 158500,
#                                 'id': 38692,
#                                 'position': 9,
#                                 'start_time': 143000,
#                                 'temperature': None},
#                                {'appliance': None,
#                                 'display_text': 'Enjoy!',
#                                 'end_time': 161333,
#                                 'id': 38693,
#                                 'position': 10,
#                                 'start_time': 159000,
#                                 'temperature': None}],
#               'is_app_only': False,
#               'is_one_top': False,
#               'is_shoppable': True,
#               'is_subscriber_content': False,
#               'keywords': 'tasty, tasty_vegetarian',
#               'language': 'eng',
#               'name': 'How To Make Vegan Pho',
#               'num_servings': 6,
#               'nutrition': {'calories': 179,
#                             'carbohydrates': 28,
#                             'fat': 5,
#                             'fiber': 7,
#                             'protein': 9,
#                             'sugar': 10,
#                             'updated_at': '2024-09-03T03:10:44+02:00'},
#               'nutrition_visibility': 'auto',
#               'original_video_url': 'https://s3.amazonaws.com/video-api-prod/assets/44fd62fb2e83447689995082d5ed7903/fb.mp4',
#               'prep_time_minutes': 480,
#               'price': {'consumption_portion': 450,
#                         'consumption_total': 2650,
#                         'portion': 1000,
#                         'total': 6100,
#                         'updated_at': '2025-10-13T07:03:18+02:00'},
#               'promotion': 'full',
#               'renditions': [{'aspect': 'square',
#                               'bit_rate': 2552,
#                               'container': 'mp4',
#                               'content_type': 'video/mp4',
#                               'duration': 176623,
#                               'file_size': 56339716,
#                               'height': 720,
#                               'maximum_bit_rate': None,
#                               'minimum_bit_rate': None,
#                               'name': 'mp4_720x720',
#                               'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/106739/square_720/1535392627_00001.png',
#                               'url': 'https://vid.tasty.co/output/106739/square_720/1535392627',
#                               'width': 720},
#                              {'aspect': 'square',
#                               'bit_rate': 834,
#                               'container': 'mp4',
#                               'content_type': 'video/mp4',
#                               'duration': 176623,
#                               'file_size': 18405132,
#                               'height': 320,
#                               'maximum_bit_rate': None,
#                               'minimum_bit_rate': None,
#                               'name': 'mp4_320x320',
#                               'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/106739/square_320/1535392627_00001.png',
#                               'url': 'https://vid.tasty.co/output/106739/square_320/1535392627',
#                               'width': 320},
#                              {'aspect': 'square',
#                               'bit_rate': 2551,
#                               'container': 'mp4',
#                               'content_type': 'video/mp4',
#                               'duration': 176623,
#                               'file_size': 56309982,
#                               'height': 720,
#                               'maximum_bit_rate': None,
#                               'minimum_bit_rate': None,
#                               'name': 'mp4_720x720',
#                               'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/106739/landscape_720/1535392627_00001.png',
#                               'url': 'https://vid.tasty.co/output/106739/landscape_720/1535392627',
#                               'width': 720},
#                              {'aspect': 'square',
#                               'bit_rate': 1451,
#                               'container': 'mp4',
#                               'content_type': 'video/mp4',
#                               'duration': 176623,
#                               'file_size': 32024947,
#                               'height': 480,
#                               'maximum_bit_rate': None,
#                               'minimum_bit_rate': None,
#                               'name': 'mp4_480x480',
#                               'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/106739/landscape_480/1535392627_00001.png',
#                               'url': 'https://vid.tasty.co/output/106739/landscape_480/1535392627',
#                               'width': 480},
#                              {'aspect': 'square',
#                               'bit_rate': None,
#                               'container': 'ts',
#                               'content_type': 'application/vnd.apple.mpegurl',
#                               'duration': 176635,
#                               'file_size': None,
#                               'height': 1080,
#                               'maximum_bit_rate': 4281,
#                               'minimum_bit_rate': 274,
#                               'name': 'low',
#                               'poster_url': 'https://img.buzzfeed.com/video-transcoder-prod/output/106739/1445289064805-h2exzu/1535392627_00001.png',
#                               'url': 'https://vid.tasty.co/output/106739/hls24_1535392627.m3u8',
#                               'width': 1080}],
#               'sections': [{'components': [{'extra_comment': '',
#                                             'id': 44901,
#                                             'ingredient': {'created_at': 1501605086,
#                                                            'display_plural': 'dried '
#                                                                              'shiitake '
#                                                                              'mushrooms',
#                                                            'display_singular': 'dried '
#                                                                                'shiitake '
#                                                                                'mushroom',
#                                                            'id': 2750,
#                                                            'name': 'dried '
#                                                                    'shiitake '
#                                                                    'mushroom',
#                                                            'updated_at': 1509035112},
#                                             'measurements': [{'id': 792001,
#                                                               'quantity': '20',
#                                                               'unit': {'abbreviation': '',
#                                                                        'display_plural': '',
#                                                                        'display_singular': '',
#                                                                        'name': '',
#                                                                        'system': 'none'}}],
#                                             'position': 1,
#                                             'raw_text': '20 dried shiitake '
#                                                         'mushrooms'},
#                                            {'extra_comment': 'tops and bottoms '
#                                                              'cut off, peeled, '
#                                                              'halved crosswise',
#                                             'id': 44902,
#                                             'ingredient': {'created_at': 1496848868,
#                                                            'display_plural': 'medium '
#                                                                              'white '
#                                                                              'onions',
#                                                            'display_singular': 'medium '
#                                                                                'white '
#                                                                                'onion',
#                                                            'id': 1560,
#                                                            'name': 'medium '
#                                                                    'white '
#                                                                    'onion',
#                                                            'updated_at': 1509035180},
#                                             'measurements': [{'id': 792016,
#                                                               'quantity': '4',
#                                                               'unit': {'abbreviation': '',
#                                                                        'display_plural': '',
#                                                                        'display_singular': '',
#                                                                        'name': '',
#                                                                        'system': 'none'}}],
#                                             'position': 2,
#                                             'raw_text': '4 medium white '
#                                                         'onions, tops and '
#                                                         'bottoms cut off, '
#                                                         'peeled, halved '
#                                                         'crosswise'},
#                                            {'extra_comment': 'peeled and cut '
#                                                              'into 1-inch- (2 '
#                                                              '1/4-cm) thick '
#                                                              'rounds',
#                                             'id': 44903,
#                                             'ingredient': {'created_at': 1535479185,
#                                                            'display_plural': 'large '
#                                                                              'daikon '
#                                                                              'radishes',
#                                                            'display_singular': 'large '
#                                                                                'daikon '
#                                                                                'radish',
#                                                            'id': 4602,
#                                                            'name': 'large '
#                                                                    'daikon '
#                                                                    'radish',
#                                                            'updated_at': 1535479185},
#                                             'measurements': [{'id': 792008,
#                                                               'quantity': '1',
#                                                               'unit': {'abbreviation': '',
#                                                                        'display_plural': '',
#                                                                        'display_singular': '',
#                                                                        'name': '',
#                                                                        'system': 'none'}}],
#                                             'position': 3,
#                                             'raw_text': '1 large daikon, '
#                                                         'peeled and cut into '
#                                                         '1-inch thick rounds'},
#                                            {'extra_comment': 'peeled, sliced '
#                                                              'into coins',
#                                             'hacks': [{'end_index': 33,
#                                                        'id': 6,
#                                                        'match': 'sliced',
#                                                        'start_index': 28}],
#                                             'id': 44904,
#                                             'ingredient': {'created_at': 1681312060,
#                                                            'display_plural': '6-inch '
#                                                                              'pieces '
#                                                                              'of '
#                                                                              'fresh '
#                                                                              'ginger',
#                                                            'display_singular': '6-inch '
#                                                                                'piece '
#                                                                                'of '
#                                                                                'fresh '
#                                                                                'ginger',
#                                                            'id': 11063,
#                                                            'name': '6-inch '
#                                                                    'piece of '
#                                                                    'fresh '
#                                                                    'ginger',
#                                                            'updated_at': 1681312060},
#                                             'measurements': [{'id': 792003,
#                                                               'quantity': '1',
#                                                               'unit': {'abbreviation': '',
#                                                                        'display_plural': '',
#                                                                        'display_singular': '',
#                                                                        'name': '',
#                                                                        'system': 'none'}}],
#                                             'position': 4,
#                                             'raw_text': '6 inches of ginger, '
#                                                         'peeled, sliced into '
#                                                         'coins'},
#                                            {'extra_comment': '',
#                                             'id': 44905,
#                                             'ingredient': {'created_at': 1506802368,
#                                                            'display_plural': 'neutral '
#                                                                              'oils',
#                                                            'display_singular': 'neutral '
#                                                                                'oil',
#                                                            'id': 3049,
#                                                            'name': 'neutral '
#                                                                    'oil',
#                                                            'updated_at': 1509035091},
#                                             'measurements': [{'id': 792009,
#                                                               'quantity': '1',
#                                                               'unit': {'abbreviation': 'tbsp',
#                                                                        'display_plural': 'tablespoons',
#                                                                        'display_singular': 'tablespoon',
#                                                                        'name': 'tablespoon',
#                                                                        'system': 'imperial'}}],
#                                             'position': 5,
#                                             'raw_text': '1 tablespoon oil'},
#                                            {'extra_comment': 'sliced into '
#                                                              '2-inch (5-cm) '
#                                                              'pieces',
#                                             'hacks': [{'end_index': 30,
#                                                        'id': 6,
#                                                        'match': 'sliced',
#                                                        'start_index': 25}],
#                                             'id': 44906,
#                                             'ingredient': {'created_at': 1681312076,
#                                                            'display_plural': 'oyster '
#                                                                              'mushrooms',
#                                                            'display_singular': 'oyster '
#                                                                                'mushroom',
#                                                            'id': 11064,
#                                                            'name': 'oyster '
#                                                                    'mushrooms',
#                                                            'updated_at': 1681312076},
#                                             'measurements': [{'id': 792011,
#                                                               'quantity': '225',
#                                                               'unit': {'abbreviation': 'g',
#                                                                        'display_plural': 'g',
#                                                                        'display_singular': 'g',
#                                                                        'name': 'gram',
#                                                                        'system': 'metric'}},
#                                                              {'id': 792006,
#                                                               'quantity': '3',
#                                                               'unit': {'abbreviation': 'c',
#                                                                        'display_plural': 'cups',
#                                                                        'display_singular': 'cup',
#                                                                        'name': 'cup',
#                                                                        'system': 'imperial'}}],
#                                             'position': 6,
#                                             'raw_text': '3 cups oyster '
#                                                         'mushrooms, sliced '
#                                                         'into 2-inch pieces'},
#                                            {'extra_comment': '',
#                                             'id': 44907,
#                                             'ingredient': {'created_at': 1494124627,
#                                                            'display_plural': 'waters',
#                                                            'display_singular': 'water',
#                                                            'id': 197,
#                                                            'name': 'water',
#                                                            'updated_at': 1509035280},
#                                             'measurements': [{'id': 792002,
#                                                               'quantity': '2.8',
#                                                               'unit': {'abbreviation': 'L',
#                                                                        'display_plural': 'L',
#                                                                        'display_singular': 'L',
#                                                                        'name': 'liter',
#                                                                        'system': 'metric'}},
#                                                              {'id': 792000,
#                                                               'quantity': '12',
#                                                               'unit': {'abbreviation': 'c',
#                                                                        'display_plural': 'cups',
#                                                                        'display_singular': 'cup',
#                                                                        'name': 'cup',
#                                                                        'system': 'imperial'}}],
#                                             'position': 7,
#                                             'raw_text': '12 cups water'},
#                                            {'extra_comment': 'to taste',
#                                             'id': 44908,
#                                             'ingredient': {'created_at': 1493307153,
#                                                            'display_plural': 'kosher '
#                                                                              'salts',
#                                                            'display_singular': 'kosher '
#                                                                                'salt',
#                                                            'id': 11,
#                                                            'name': 'kosher '
#                                                                    'salt',
#                                                            'updated_at': 1509035289},
#                                             'measurements': [{'id': 792015,
#                                                               'quantity': '0',
#                                                               'unit': {'abbreviation': '',
#                                                                        'display_plural': '',
#                                                                        'display_singular': '',
#                                                                        'name': '',
#                                                                        'system': 'none'}}],
#                                             'position': 8,
#                                             'raw_text': 'Salt, to taste'},
#                                            {'extra_comment': 'or piece of '
#                                                              'cassia bark',
#                                             'id': 44909,
#                                             'ingredient': {'created_at': 1496147892,
#                                                            'display_plural': 'cinnamon '
#                                                                              'sticks',
#                                                            'display_singular': 'cinnamon '
#                                                                                'stick',
#                                                            'id': 948,
#                                                            'name': 'cinnamon '
#                                                                    'stick',
#                                                            'updated_at': 1509035220},
#                                             'measurements': [{'id': 792018,
#                                                               'quantity': '1',
#                                                               'unit': {'abbreviation': '',
#                                                                        'display_plural': '',
#                                                                        'display_singular': '',
#                                                                        'name': '',
#                                                                        'system': 'none'}}],
#                                             'position': 9,
#                                             'raw_text': '1 cinnamon stick or '
#                                                         'piece of cassia bark'},
#                                            {'extra_comment': '',
#                                             'id': 44910,
#                                             'ingredient': {'created_at': 1670259892,
#                                                            'display_plural': 'whole '
#                                                                              'cloves',
#                                                            'display_singular': 'whole '
#                                                                                'clove',
#                                                            'id': 10551,
#                                                            'name': 'whole '
#                                                                    'cloves',
#                                                            'updated_at': 1670259892},
#                                             'measurements': [{'id': 792004,
#                                                               'quantity': '1',
#                                                               'unit': {'abbreviation': 'tsp',
#                                                                        'display_plural': 'teaspoons',
#                                                                        'display_singular': 'teaspoon',
#                                                                        'name': 'teaspoon',
#                                                                        'system': 'imperial'}}],
#                                             'position': 10,
#                                             'raw_text': '1 teaspoon cloves'},
#                                            {'extra_comment': '',
#                                             'id': 44911,
#                                             'ingredient': {'created_at': 1533834237,
#                                                            'display_plural': 'cardamom '
#                                                                              'pods',
#                                                            'display_singular': 'cardamom '
#                                                                                'pod',
#                                                            'id': 4555,
#                                                            'name': 'cardamom '
#                                                                    'pods',
#                                                            'updated_at': 1533834237},
#                                             'measurements': [{'id': 792012,
#                                                               'quantity': '5',
#                                                               'unit': {'abbreviation': '',
#                                                                        'display_plural': '',
#                                                                        'display_singular': '',
#                                                                        'name': '',
#                                                                        'system': 'none'}}],
#                                             'position': 11,
#                                             'raw_text': '5-6 cardamom pods'},
#                                            {'extra_comment': '',
#                                             'id': 44912,
#                                             'ingredient': {'created_at': 1495217932,
#                                                            'display_plural': 'star '
#                                                                              'anises',
#                                                            'display_singular': 'star '
#                                                                                'anise',
#                                                            'id': 526,
#                                                            'name': 'star anise',
#                                                            'updated_at': 1509035253},
#                                             'measurements': [{'id': 792013,
#                                                               'quantity': '5',
#                                                               'unit': {'abbreviation': '',
#                                                                        'display_plural': '',
#                                                                        'display_singular': '',
#                                                                        'name': '',
#                                                                        'system': 'none'}}],
#                                             'position': 12,
#                                             'raw_text': '5-6 pieces of star '
#                                                         'anise'},
#                                            {'extra_comment': '',
#                                             'id': 44913,
#                                             'ingredient': {'created_at': 1501347926,
#                                                            'display_plural': 'coriander '
#                                                                              'seeds',
#                                                            'display_singular': 'coriander '
#                                                                                'seed',
#                                                            'id': 2697,
#                                                            'name': 'coriander '
#                                                                    'seed',
#                                                            'updated_at': 1509035116},
#                                             'measurements': [{'id': 792005,
#                                                               'quantity': '1',
#                                                               'unit': {'abbreviation': 'tbsp',
#                                                                        'display_plural': 'tablespoons',
#                                                                        'display_singular': 'tablespoon',
#                                                                        'name': 'tablespoon',
#                                                                        'system': 'imperial'}}],
#                                             'position': 13,
#                                             'raw_text': '1 tablespoon '
#                                                         'coriander seeds'},
#                                            {'extra_comment': '',
#                                             'id': 44914,
#                                             'ingredient': {'created_at': 1535479236,
#                                                            'display_plural': 'fennel '
#                                                                              'seeds',
#                                                            'display_singular': 'fennel '
#                                                                                'seed',
#                                                            'id': 4603,
#                                                            'name': 'fennel '
#                                                                    'seeds',
#                                                            'updated_at': 1535479236},
#                                             'measurements': [{'id': 792007,
#                                                               'quantity': '1',
#                                                               'unit': {'abbreviation': 'tsp',
#                                                                        'display_plural': 'teaspoons',
#                                                                        'display_singular': 'teaspoon',
#                                                                        'name': 'teaspoon',
#                                                                        'system': 'imperial'}}],
#                                             'position': 14,
#                                             'raw_text': '1 teaspoon fennel '
#                                                         'seeds'},
#                                            {'extra_comment': 'drained and '
#                                                              'sliced into '
#                                                              '1-inch (2-cm) '
#                                                              'pieces, or fried '
#                                                              'tofu, sliced',
#                                             'hacks': [{'end_index': 50,
#                                                        'id': 6,
#                                                        'match': 'sliced',
#                                                        'start_index': 45}],
#                                             'id': 44915,
#                                             'ingredient': {'created_at': 1507175027,
#                                                            'display_plural': 'soft '
#                                                                              'tofus',
#                                                            'display_singular': 'soft '
#                                                                                'tofu',
#                                                            'id': 3064,
#                                                            'name': 'soft tofu',
#                                                            'updated_at': 1509035090},
#                                             'measurements': [{'id': 792023,
#                                                               'quantity': '14',
#                                                               'unit': {'abbreviation': 'oz',
#                                                                        'display_plural': 'oz',
#                                                                        'display_singular': 'oz',
#                                                                        'name': 'ounce',
#                                                                        'system': 'imperial'}},
#                                                              {'id': 792021,
#                                                               'quantity': '400',
#                                                               'unit': {'abbreviation': 'g',
#                                                                        'display_plural': 'g',
#                                                                        'display_singular': 'g',
#                                                                        'name': 'gram',
#                                                                        'system': 'metric'}},
#                                                              {'id': 792020,
#                                                               'quantity': '1',
#                                                               'unit': {'abbreviation': 'package',
#                                                                        'display_plural': 'packages',
#                                                                        'display_singular': 'package',
#                                                                        'name': 'package',
#                                                                        'system': 'none'}}],
#                                             'position': 15,
#                                             'raw_text': '1 400-gram package of '
#                                                         'soft tofu, drained '
#                                                         'and sliced into '
#                                                         '1-inch pieces, or '
#                                                         'fried tofu, sliced'}],
#                             'name': None,
#                             'position': 1},
#                            {'components': [{'extra_comment': '',
#                                             'id': 44917,
#                                             'ingredient': {'created_at': 1681312137,
#                                                            'display_plural': 'cooked '
#                                                                              'rice '
#                                                                              'stick '
#                                                                              'noodles',
#                                                            'display_singular': 'cooked '
#                                                                                'rice '
#                                                                                'stick '
#                                                                                'noodle',
#                                                            'id': 11065,
#                                                            'name': 'cooked '
#                                                                    'rice stick '
#                                                                    'noodles',
#                                                            'updated_at': 1681312137},
#                                             'measurements': [{'id': 792019,
#                                                               'quantity': '0',
#                                                               'unit': {'abbreviation': '',
#                                                                        'display_plural': '',
#                                                                        'display_singular': '',
#                                                                        'name': '',
#                                                                        'system': 'none'}}],
#                                             'position': 17,
#                                             'raw_text': 'cooked rice stick '
#                                                         'noodles'},
# ...
#                                                                              'pastes',
#                                                            'display_singular': 'chilli '
#                                                                                'paste',
#                                                            'id': 6806,
#                                                            'name': 'chilli '
#                                                                    'paste',
#                                                            'updated_at': 1599141851},
#                                             'measurements': [{'id': 591644,
#                                                               'quantity': '1',
#                                                               'unit': {'abbreviation': 'tsp',
#                                                                        'display_plural': 'teaspoons',
#                                                                        'display_singular': 'teaspoon',
#                                                                        'name': 'teaspoon',
#                                                                        'system': 'imperial'}}],
#                                             'position': 13,
#                                             'raw_text': '1 tsp chilli paste'}],
#                             'name': 'To garnish:',
#                             'position': 2}],
#               'seo_path': '8757513,9295873,64448',
#               'seo_title': '',
#               'servings_noun_plural': 'servings',
#               'servings_noun_singular': 'serving',
#               'show': {'id': 17, 'name': 'Tasty'},
#               'show_id': 17,
#               'slug': 'fried-carrot-cake',
#               'tags': [{'display_name': 'Chinese',
#                         'id': 64448,
#                         'name': 'chinese',
#                         'parent_tag_name': 'asian',
#                         'root_tag_type': 'cuisine',
#                         'type': 'asian'},
#                        {'display_name': 'Seafood',
#                         'id': 64459,
#                         'name': 'seafood',
#                         'parent_tag_name': 'dinner',
#                         'root_tag_type': 'meal',
#                         'type': 'dinner'},
#                        {'display_name': 'Comfort Food',
#                         'id': 64462,
#                         'name': 'comfort_food',
#                         'parent_tag_name': 'cooking_style',
#                         'root_tag_type': 'cooking_style',
#                         'type': 'cooking_style'},
#                        {'display_name': 'Dairy-Free',
#                         'id': 64463,
#                         'name': 'dairy_free',
#                         'parent_tag_name': 'dietary',
#                         'root_tag_type': 'dietary',
#                         'type': 'dietary'},
#                        {'display_name': 'Healthy',
#                         'id': 64466,
#                         'name': 'healthy',
#                         'parent_tag_name': None,
#                         'root_tag_type': 'healthy',
#                         'type': 'healthy'},
#                        {'display_name': 'Appetizers',
#                         'id': 64481,
#                         'name': 'appetizers',
#                         'parent_tag_name': 'meal',
#                         'root_tag_type': 'meal',
#                         'type': 'meal'},
#                        {'display_name': 'Brunch',
#                         'id': 64484,
#                         'name': 'brunch',
#                         'parent_tag_name': 'meal',
#                         'root_tag_type': 'meal',
#                         'type': 'meal'},
#                        {'display_name': 'Dinner',
#                         'id': 64486,
#                         'name': 'dinner',
#                         'parent_tag_name': 'meal',
#                         'root_tag_type': 'meal',
#                         'type': 'meal'},
#                        {'display_name': 'Lunch',
#                         'id': 64489,
#                         'name': 'lunch',
#                         'parent_tag_name': 'meal',
#                         'root_tag_type': 'meal',
#                         'type': 'meal'},
#                        {'display_name': 'Snacks',
#                         'id': 64491,
#                         'name': 'snacks',
#                         'parent_tag_name': 'meal',
#                         'root_tag_type': 'meal',
#                         'type': 'meal'},
#                        {'display_name': 'Deep-Fry',
#                         'id': 64493,
#                         'name': 'deep_fry',
#                         'parent_tag_name': 'cooking_style',
#                         'root_tag_type': 'cooking_style',
#                         'type': 'cooking_style'},
#                        {'display_name': 'Steam',
#                         'id': 64498,
#                         'name': 'steam',
#                         'parent_tag_name': 'cooking_style',
#                         'root_tag_type': 'cooking_style',
#                         'type': 'cooking_style'},
#                        {'display_name': 'Date Night',
#                         'id': 64500,
#                         'name': 'date_night',
#                         'parent_tag_name': 'occasion',
#                         'root_tag_type': 'seasonal',
#                         'type': 'occasion'},
#                        {'display_name': 'Game Day',
#                         'id': 64501,
#                         'name': 'game_day',
#                         'parent_tag_name': 'occasion',
#                         'root_tag_type': 'seasonal',
#                         'type': 'occasion'},
#                        {'display_name': 'Party',
#                         'id': 64503,
#                         'name': 'party',
#                         'parent_tag_name': 'occasion',
#                         'root_tag_type': 'seasonal',
#                         'type': 'occasion'},
#                        {'display_name': 'Fusion',
#                         'id': 65410,
#                         'name': 'fusion',
#                         'parent_tag_name': 'cuisine',
#                         'root_tag_type': 'cuisine',
#                         'type': 'cuisine'},
#                        {'display_name': 'Stove Top',
#                         'id': 65848,
#                         'name': 'stove_top',
#                         'parent_tag_name': None,
#                         'root_tag_type': 'appliance',
#                         'type': 'appliance'},
#                        {'display_name': 'Wok',
#                         'id': 65849,
#                         'name': 'wok',
#                         'parent_tag_name': 'appliance',
#                         'root_tag_type': 'appliance',
#                         'type': 'appliance'},
#                        {'display_name': 'Meal Prep',
#                         'id': 65853,
#                         'name': 'meal_prep',
#                         'parent_tag_name': 'cooking_style',
#                         'root_tag_type': 'cooking_style',
#                         'type': 'cooking_style'},
#                        {'display_name': 'One-Pot or Pan',
#                         'id': 65855,
#                         'name': 'one_pot_or_pan',
#                         'parent_tag_name': 'cooking_style',
#                         'root_tag_type': 'cooking_style',
#                         'type': 'cooking_style'},
#                        {'display_name': 'Pan Fry',
#                         'id': 65859,
#                         'name': 'pan_fry',
#                         'parent_tag_name': 'cooking_style',
#                         'root_tag_type': 'cooking_style',
#                         'type': 'cooking_style'},
#                        {'display_name': 'Special Occasion',
#                         'id': 188967,
#                         'name': 'special_occasion',
#                         'parent_tag_name': 'occasion',
#                         'root_tag_type': 'seasonal',
#                         'type': 'occasion'},
#                        {'display_name': 'Spatula',
#                         'id': 1247788,
#                         'name': 'spatula',
#                         'parent_tag_name': None,
#                         'root_tag_type': 'equipment',
#                         'type': 'equipment'},
#                        {'display_name': "Chef's Knife",
#                         'id': 1280501,
#                         'name': 'chefs_knife',
#                         'parent_tag_name': None,
#                         'root_tag_type': 'equipment',
#                         'type': 'equipment'},
#                        {'display_name': 'Cutting Board',
#                         'id': 1280503,
#                         'name': 'cutting_board',
#                         'parent_tag_name': None,
#                         'root_tag_type': 'equipment',
#                         'type': 'equipment'},
#                        {'display_name': 'Mixing Bowl',
#                         'id': 1280510,
#                         'name': 'mixing_bowl',
#                         'parent_tag_name': None,
#                         'root_tag_type': 'equipment',
#                         'type': 'equipment'},
#                        {'display_name': 'Under 1 Hour',
#                         'id': 8091748,
#                         'name': 'under_1_hour',
#                         'parent_tag_name': 'difficulty',
#                         'root_tag_type': 'difficulty',
#                         'type': 'difficulty'},
#                        {'display_name': 'Low-Calorie',
#                         'id': 8091916,
#                         'name': 'low_calorie',
#                         'parent_tag_name': 'healthy',
#                         'root_tag_type': 'healthy',
#                         'type': 'healthy'},
#                        {'display_name': 'High-Protein',
#                         'id': 8091917,
#                         'name': 'high_protein',
#                         'parent_tag_name': 'healthy',
#                         'root_tag_type': 'healthy',
#                         'type': 'healthy'},
#                        {'display_name': 'Low-Sugar',
#                         'id': 8091918,
#                         'name': 'low_sugar',
#                         'parent_tag_name': 'healthy',
#                         'root_tag_type': 'healthy',
#                         'type': 'healthy'},
#                        {'display_name': 'High-Fiber',
#                         'id': 8091920,
#                         'name': 'high_fiber',
#                         'parent_tag_name': 'healthy',
#                         'root_tag_type': 'healthy',
#                         'type': 'healthy'},
#                        {'display_name': 'Cooking Style',
#                         'id': 9295810,
#                         'name': 'cooking_style',
#                         'parent_tag_name': None,
#                         'root_tag_type': 'cooking_style',
#                         'type': 'cooking_style'},
#                        {'display_name': 'Appliance',
#                         'id': 9295811,
#                         'name': 'appliance',
#                         'parent_tag_name': None,
#                         'root_tag_type': 'appliance',
#                         'type': 'appliance'},
#                        {'display_name': 'Meal',
#                         'id': 9295813,
#                         'name': 'meal',
#                         'parent_tag_name': None,
#                         'root_tag_type': 'meal',
#                         'type': 'meal'},
#                        {'display_name': 'Dietary',
#                         'id': 9295814,
#                         'name': 'dietary',
#                         'parent_tag_name': None,
#                         'root_tag_type': 'dietary',
#                         'type': 'dietary'},
#                        {'display_name': 'Difficulty',
#                         'id': 9295816,
#                         'name': 'difficulty',
#                         'parent_tag_name': None,
#                         'root_tag_type': 'difficulty',
#                         'type': 'difficulty'},
#                        {'display_name': 'Asian',
#                         'id': 9295873,
#                         'name': 'asian',
#                         'parent_tag_name': 'cuisine',
#                         'root_tag_type': 'cuisine',
#                         'type': 'cuisine'},
#                        {'display_name': 'Occasion',
#                         'id': 9299134,
#                         'name': 'occasion',
#                         'parent_tag_name': 'seasonal',
#                         'root_tag_type': 'seasonal',
#                         'type': 'seasonal'},
#                        {'display_name': 'Egg Breakfasts',
#                         'id': 9299366,
#                         'name': 'egg_breakfasts',
#                         'parent_tag_name': 'breakfast',
#                         'root_tag_type': 'meal',
#                         'type': 'breakfast'},
#                        {'display_name': 'Chicken',
#                         'id': 9299514,
#                         'name': 'chicken',
#                         'parent_tag_name': 'dinner',
#                         'root_tag_type': 'meal',
#                         'type': 'dinner'},
#                        {'display_name': 'Eggs',
#                         'id': 10623588,
#                         'name': 'eggs',
#                         'parent_tag_name': 'ingredients_to_avoid',
#                         'root_tag_type': 'ingredients_to_avoid',
#                         'type': 'ingredients_to_avoid'},
#                        {'display_name': 'Gluten',
#                         'id': 10623589,
#                         'name': 'gluten',
#                         'parent_tag_name': 'ingredients_to_avoid',
#                         'root_tag_type': 'ingredients_to_avoid',
#                         'type': 'ingredients_to_avoid'},
#                        {'display_name': 'Soy',
#                         'id': 10623590,
#                         'name': 'soy',
#                         'parent_tag_name': 'ingredients_to_avoid',
#                         'root_tag_type': 'ingredients_to_avoid',
#                         'type': 'ingredients_to_avoid'},
#                        {'display_name': 'Chicken',
#                         'id': 10623612,
#                         'name': 'chicken',
#                         'parent_tag_name': 'ingredients_to_avoid',
#                         'root_tag_type': 'ingredients_to_avoid',
#                         'type': 'ingredients_to_avoid'}],
#               'thumbnail_alt_text': '',
#               'thumbnail_url': 'https://img.buzzfeed.com/thumbnailer-prod-us-east-1/video-api/assets/269167.jpg',
#               'tips_and_ratings_enabled': True,
#               'topics': [{'name': 'Sunday Brunch', 'slug': 'brunch'},
#                          {'name': 'Healthy Eating', 'slug': 'healthy'},
#                          {'name': 'Weekend Meal Prep', 'slug': 'meal-prep'},
#                          {'name': 'One-Pot Recipes', 'slug': 'one-pot'},
#                          {'name': 'Romantic Dinners',
#                           'slug': 'romantic-dinners'},
#                          {'name': 'Spring Recipes', 'slug': 'spring-recipes'},
#                          {'name': 'Lunch', 'slug': 'lunch'},
#                          {'name': 'Dinner', 'slug': 'dinner'},
#                          {'name': 'Snacks', 'slug': 'snacks'},
#                          {'name': 'Chinese', 'slug': 'chinese'}],
#               'total_time_minutes': 270,
#               'total_time_tier': None,
#               'updated_at': 1600120800,
#               'user_ratings': {'count_negative': 9,
#                                'count_positive': 28,
#                                'score': 0.7567567567567568},
#               'video_ad_content': 'co_branded',
#               'video_id': 107157,
#               'video_url': 'https://vid.tasty.co/output/170020/hls24_1591831158.m3u8',
#               'yields': 'Servings: 8'}]}

# %%
daikon_recipes = pd.json_normalize(response.json(), "results") #turns json to pandas
daikon_recipes
# Out:
#     approved_at aspect_ratio  \
# 0    1561944458          1:1
# 1    1570199933          1:1
# 2    1582749647          1:1
# 3    1533335386          1:1
# 4    1544035794          1:1
# 5    1540495868          1:1
# 6    1553696219          1:1
# 7    1528771181          1:1
# 8    1616591279         16:9
# 9    1558026831          1:1
# 10   1568686659          1:1
# 11   1561741987         None
# 12   1740152780         9:16
# 13   1599224363          1:1
#
#                                            beauty_url  brand  brand_id  \
# 0   https://img.buzzfeed.com/video-api-prod/assets...    NaN       NaN
# 1                                                None    NaN       NaN
# 2                                                None    NaN       NaN
# 3   https://img.buzzfeed.com/video-api-prod/assets...    NaN       NaN
# 4   https://img.buzzfeed.com/video-api-prod/assets...    NaN       NaN
# 5                                                None    NaN       NaN
# 6                                                None    NaN       NaN
# 7   https://img.buzzfeed.com/video-api-prod/assets...    NaN       NaN
# 8                                                None    NaN       NaN
# 9                                                None    NaN       NaN
# 10                                               None    NaN       NaN
# 11                                               None    NaN       NaN
# 12                                               None    NaN       NaN
# 13                                               None    NaN      24.0
#
#    buzz_id canonical_id                                       compilations  \
# 0     None  recipe:4326                                                 []
# 1     None  recipe:5643  [{'approved_at': 1607958492, 'aspect_ratio': '...
# 2     None  recipe:6046  [{'approved_at': 1715722012, 'aspect_ratio': '...
# 3     None  recipe:4258  [{'approved_at': 1538682187, 'aspect_ratio': '...
# 4     None  recipe:4621  [{'approved_at': 1547056260, 'aspect_ratio': '...
# 5     None  recipe:4490  [{'approved_at': 1540496546, 'aspect_ratio': '...
# 6     None  recipe:4711  [{'approved_at': 1620307223, 'aspect_ratio': '...
# 7     None  recipe:4013  [{'approved_at': 1625153900, 'aspect_ratio': '...
# 8     None  recipe:7224  [{'approved_at': 1616591289, 'aspect_ratio': '...
# 9     None  recipe:5152  [{'approved_at': 1611844728, 'aspect_ratio': '...
# 10    None  recipe:5593  [{'approved_at': 1568686669, 'aspect_ratio': '...
# 11    None  recipe:5375  [{'approved_at': 1569467385, 'aspect_ratio': '...
# 12    None  recipe:9225                                                 []
# 13    None  recipe:6542                                                 []
#
#     cook_time_minutes country  ...  tips_summary.header  \
# 0                  90      US  ...           Highlights
# 1                  20      US  ...                  NaN
# 2                  40      US  ...           Highlights
# 3                   0      US  ...           Highlights
# 4                  20      US  ...                  NaN
# 5                   8      US  ...                  NaN
# 6                  60      US  ...                  NaN
# 7                  30      US  ...           Highlights
# 8                   5      US  ...                  NaN
# 9                  30      US  ...                  NaN
# 10                 10      US  ...                  NaN
# 11                  0      US  ...                  NaN
# 12                195      US  ...                  NaN
# 13                 75      US  ...                  NaN
#
#    user_ratings.count_negative user_ratings.count_positive user_ratings.score  \
# 0                           35                         101           0.742647
# 1                            4                         102           0.962264
# 2                           22                         105           0.826772
# 3                           13                         109           0.893443
# 4                           17                         128           0.882759
# 5                            1                          35           0.972222
# 6                           30                         377           0.926290
# 7                            7                         156           0.957055
# 8                            9                          61           0.871429
# 9                            6                          88           0.936170
# 10                           3                          25           0.892857
# 11                           3                          64           0.955224
# 12                           1                          14           0.933333
# 13                           9                          28           0.756757
#
#    total_time_tier.display_tier  total_time_tier.tier brand.id  \
# 0                           NaN                   NaN      NaN
# 1                 Under 2 hours         under_2_hours      NaN
# 2                           NaN                   NaN      NaN
# 3               Under 2.5 hours       under_2.5_hours      NaN
# 4              Under 45 minutes      under_45_minutes      NaN
# 5              Under 30 minutes      under_30_minutes      NaN
# 6                           NaN                   NaN      NaN
# 7               Under 1.5 hours       under_1.5_hours      NaN
# 8              Under 15 minutes      under_15_minutes      NaN
# 9                           NaN                   NaN      NaN
# 10             Under 45 minutes      under_45_minutes      NaN
# 11             Under 30 minutes      under_30_minutes      NaN
# 12                          NaN                   NaN      NaN
# 13                          NaN                   NaN     24.0
#
#                                       brand.image_url      brand.name  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# 5                                                 NaN             NaN
# 6                                                 NaN             NaN
# 7                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9                                                 NaN             NaN
# 10                                                NaN             NaN
# 11                                                NaN             NaN
# 12                                                NaN             NaN
# 13  https://img.buzzfeed.com/tasty-app-user-assets...  VisitSingapore
#
#         brand.slug
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13  visitsingapore
#
# [14 rows x 76 columns]

# %% [markdown]
# ## Scraping an HTML table with Beautiful Soup

# %% [markdown]
# Open the URL https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population and scroll down until you see a table of the cities in the U.S. with population over 100,000 (as of Jul 1, 2022). We'll use Beautiful Soup to scrape information from this table.

# %% [markdown]
# Read in the HTML from the ULR using the `requests` library.

# %%
URL = "https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population"
HEADERS = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}

# %%
response = requests.get(URL, headers=HEADERS)

# %%
pprint(response.content)
# Out:
# (b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-head'
#  b'er-enabled vector-feature-language-in-main-page-header-disabled vector-featu'
#  b're-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-'
#  b'feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 '
#  b'vector-feature-limited-width-content-enabled vector-feature-custom-font-size'
#  b'-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-n'
#  b'ight-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vec'
#  b'tor-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<t'
#  b'itle>List of United States cities by population - Wikipedia</title>\n<scr'
#  b'ipt>(function(){var className="client-js vector-feature-language-in-header-e'
#  b'nabled vector-feature-language-in-main-page-header-disabled vector-feature-p'
#  b'age-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feat'
#  b'ure-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vect'
#  b'or-feature-limited-width-content-enabled vector-feature-custom-font-size-cli'
#  b'entpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night'
#  b'-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-'
#  b'toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientprefe'
#  b"rences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){cl"
#  b"assName=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\\"
#  b"w+$|[^\\w-]+/g,'')+'-clientpref-\\\\w+( |$)'),'$1'+pref+'$2');});}document."
#  b'documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSe'
#  b'paratorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDat'
#  b'eFormat":"dmy","wgMonthNames":["","January","February","March","April","May"'
#  b',"June","July","August","September","October","November","December"],"wgRequ'
#  b'estId":"d9d0a497-f770-4886-903d-23b20d1199bf","wgCanonicalNamespace":"","wgC'
#  b'anonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_U'
#  b'nited_States_cities_by_population","wgTitle":"List of United States cities b'
#  b'y population","wgCurRevisionId":1310334705,"wgRevisionId":1310334705,"wgArti'
#  b'cleId":1649321,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wg'
#  b'UserName":null,"wgUserGroups":["*"],"wgCategories":["Webarchive template way'
#  b'back links","Articles with short description","Short description is differen'
#  b't from Wikidata","Wikipedia indefinitely semi-protected pages","Use mdy date'
#  b's from April 2023","Lists of coordinates","Geographic coordinate lists","Art'
#  b'icles with Geo","Pages using gadget WikiMiniAtlas","Pages using gallery with'
#  b'out a media namespace prefix","Articles containing Spanish-language text","A'
#  b'll articles with unsourced statements","Articles with unsourced statements f'
#  b'rom May 2025","Pages using Sister project links with wikidata namespace mism'
#  b'atch","Pages using Sister project links with wikidata mismatch","Pages using'
#  b' Sister project links with default search","Featured lists","Lists of cities'
#  b' in the United States by population","United States demography-related lists'
#  b'","Demographics in the United States by populated place"],"wgPageViewLanguag'
#  b'e":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRele'
#  b'vantPageName":"List_of_United_States_cities_by_population","wgRelevantArticl'
#  b'eId":1649321,"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable"'
#  b':false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":["autoconfi'
#  b'rmed"],"wgNoticeProject":"wikipedia","wgFlaggedRevsParams":{"tags":{"status"'
#  b':{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":'
#  b'true,"wgPopupsFlags":0,"wgVisualEditor":{"pageLanguageCode":"en","pageLangua'
#  b'geDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":'
#  b'{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaE'
#  b'ditAttemptStepOversample":false,"wgWMEPageLength":100000,"wgMetricsPlatformU'
#  b'serExperiments":{"active_experiments":[],"overrides":[],"enrolled":[],"assig'
#  b'ned":[],"subject_ids":[],"sampling_units":[]},"wgEditSubmitButtonLabelPublis'
#  b'h":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"'
#  b'wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgW'
#  b'ikibaseItemId":"Q131079","wgCheckUserClientHintsHeadersJsApi":["brands","arc'
#  b'hitecture","bitness","fullVersionList","mobile","model","platform","platform'
#  b'Version"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGESuggestedEditsTas'
#  b'kTypes":{"taskTypes":["copyedit","link-recommendation"],"unavailableTaskType'
#  b's":[]},"wgGETopicsMatchModeEnabled":false,"wgGELevelingUpEnabledForUser":fal'
#  b'se};\nRLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready'
#  b'","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.'
#  b'options":"loading","ext.cite.styles":"ready","mediawiki.page.gallery.styles"'
#  b':"ready","ext.wikimediamessages.styles":"ready","skins.vector.search.codex.s'
#  b'tyles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","j'
#  b'query.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","e'
#  b'xt.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguag'
#  b'e":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLP'
#  b'AGEMODULES=["ext.xLab","ext.cite.ux-enhancements","mediawiki.page.media","si'
#  b'te","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","me'
#  b'diawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.'
#  b'startUp","ext.gadget.ReferenceTooltips","ext.gadget.switcher","ext.gadget.Wi'
#  b'kiMiniAtlas","ext.urlShortener.toolbar","ext.centralauth.centralautologin","'
#  b'mmv.bootstrap","ext.popups","ext.visualEditor.desktopArticleTarget.init","ex'
#  b't.visualEditor.targetLoader","ext.echo.centralauth","ext.eventLogging","ext.'
#  b'wikimediaEvents","ext.navigationTiming","ext.uls.interface","ext.cx.eventlog'
#  b'ging.campaigns","ext.cx.uls.quick.actions","wikibase.client.vector-2022","ex'
#  b't.checkUser.clientHints","ext.growthExperiments.SuggestedEditSession"];</scr'
#  b'ipt>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.impl(functio'
#  b'n(){return["user.options@12s5i",function($,jQuery,require,module){mw.user.to'
#  b'kens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"})'
#  b';\n}];});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&am'
#  b'p;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktop'
#  b'ArticleTarget.noscript%7Cext.wikimediaBadges%7Cext.wikimediamessages.styles%'
#  b'7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cmediawiki.page'
#  b'.gallery.styles%7Cskins.vector.icons%2Cstyles%7Cskins.vector.search.codex.st'
#  b'yles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector-2022">\n<scri'
#  b'pt async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&am'
#  b'p;raw=1&amp;skin=vector-2022"></script>\n<meta name="ResourceLoaderDynami'
#  b'cStyles" content="">\n<link rel="stylesheet" href="/w/load.php?lang=en&am'
#  b'p;modules=site.styles&amp;only=styles&amp;skin=vector-2022">\n<meta name='
#  b'"generator" content="MediaWiki 1.45.0-wmf.22">\n<meta name="referrer" con'
#  b'tent="origin">\n<meta name="referrer" content="origin-when-cross-origin">'
#  b'\n<meta name="robots" content="max-image-preview:standard">\n<meta name="f'
#  b'ormat-detection" content="telephone=no">\n<meta property="og:image" conte'
#  b'nt="https://upload.wikimedia.org/wikipedia/commons/thumb/7/7a/View_of_Empire'
#  b'_State_Building_from_Rockefeller_Center_New_York_City_dllu_%28cropped%29.jpg'
#  b'/1200px-View_of_Empire_State_Building_from_Rockefeller_Center_New_York_City_'
#  b'dllu_%28cropped%29.jpg">\n<meta property="og:image:width" content="1200">'
#  b'\n<meta property="og:image:height" content="675">\n<meta name="viewport" c'
#  b'ontent="width=1120">\n<meta property="og:title" content="List of United S'
#  b'tates cities by population - Wikipedia">\n<meta property="og:type" conten'
#  b't="website">\n<link rel="preconnect" href="//upload.wikimedia.org">\n<link'
#  b' rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png">\n<link '
#  b'rel="icon" href="/static/favicon/wikipedia.ico">\n<link rel="search" type'
#  b'="application/opensearchdescription+xml" href="/w/rest.php/v1/search" title='
#  b'"Wikipedia (en)">\n<link rel="EditURI" type="application/rsd+xml" href="/'
#  b'/en.wikipedia.org/w/api.php?action=rsd">\n<link rel="canonical" href="htt'
#  b'ps://en.wikipedia.org/wiki/List_of_United_States_cities_by_population">\n'
#  b'<link rel="license" href="https://creativecommons.org/licenses/by-sa/4.0/dee'
#  b'd.en">\n<link rel="alternate" type="application/atom+xml" title="Wikipedi'
#  b'a Atom feed" href="/w/index.php?title=Special:RecentChanges&amp;feed=ato'
#  b'm">\n<link rel="dns-prefetch" href="//meta.wikimedia.org" />\n<link rel="d'
#  b'ns-prefetch" href="auth.wikimedia.org">\n</head>\n<body class="skin--respo'
#  b'nsive skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-e'
#  b'mpty-elt ns-0 ns-subject page-List_of_United_States_cities_by_population roo'
#  b'tpage-List_of_United_States_cities_by_population skin-vector-2022 action-vie'
#  b'w"><a class="mw-jump-link" href="#bodyContent">Jump to content</a>\n<div '
#  b'class="vector-header-container">\n\t<header class="vector-header mw-header'
#  b' no-font-mode-scale">\n\t\t<div class="vector-header-start">\n\t\t\t<nav cl'
#  b'ass="vector-main-menu-landmark" aria-label="Site">\n\t\t\t\t\n<div id="vec'
#  b'tor-main-menu-dropdown" class="vector-dropdown vector-main-menu-dropdown vec'
#  b'tor-button-flush-left vector-button-flush-right"  title="Main menu" >\n\t<'
#  b'input type="checkbox" id="vector-main-menu-dropdown-checkbox" role="button" '
#  b'aria-haspopup="true" data-event-name="ui.dropdown-vector-main-menu-dropdown"'
#  b' class="vector-dropdown-checkbox "  aria-label="Main menu"  >\n\t<label id'
#  b'="vector-main-menu-dropdown-label" for="vector-main-menu-dropdown-checkbox" '
#  b'class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--'
#  b'fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only " aria-h'
#  b'idden="true"  ><span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia'
#  b'-menu"></span>\n\n<span class="vector-dropdown-label-text">Main menu</span'
#  b'>\n\t</label>\n\t<div class="vector-dropdown-content">\n\n\n\t\t\t\t<div id'
#  b'="vector-main-menu-unpinned-container" class="vector-unpinned-container"'
#  b'>\n\t\t\n<div id="vector-main-menu" class="vector-main-menu vector-pinnable-'
#  b'element">\n\t<div\n\tclass="vector-pinnable-header vector-main-menu-pinnable'
#  b'-header vector-pinnable-header-unpinned"\n\tdata-feature-name="main-menu-p'
#  b'inned"\n\tdata-pinnable-element-id="vector-main-menu"\n\tdata-pinned-contain'
#  b'er-id="vector-main-menu-pinned-container"\n\tdata-unpinned-container-id="v'
#  b'ector-main-menu-unpinned-container"\n>\n\t<div class="vector-pinnable-heade'
#  b'r-label">Main menu</div>\n\t<button class="vector-pinnable-header-toggle-b'
#  b'utton vector-pinnable-header-pin-button" data-event-name="pinnable-header.ve'
#  b'ctor-main-menu.pin">move to sidebar</button>\n\t<button class="vector-pinn'
#  b'able-header-toggle-button vector-pinnable-header-unpin-button" data-event-na'
#  b'me="pinnable-header.vector-main-menu.unpin">hide</button>\n</div>\n\n\t\n'
#  b'<div id="p-navigation" class="vector-menu mw-portlet mw-portlet-navigation" '
#  b' >\n\t<div class="vector-menu-heading">\n\t\tNavigation\n\t</div>\n\t<div'
#  b' class="vector-menu-content">\n\t\t\n\t\t<ul class="vector-menu-content-li'
#  b'st">\n\t\t\t\n\t\t\t<li id="n-mainpage-description" class="mw-list-item"><a '
#  b'href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z"><span>M'
#  b'ain page</span></a></li><li id="n-contents" class="mw-list-item"><a href="/w'
#  b'iki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents<'
#  b'/span></a></li><li id="n-currentevents" class="mw-list-item"><a href="/wiki/'
#  b'Portal:Current_events" title="Articles related to current events"><span>Curr'
#  b'ent events</span></a></li><li id="n-randompage" class="mw-list-item"><a href'
#  b'="/wiki/Special:Random" title="Visit a randomly selected article [x]" access'
#  b'key="x"><span>Random article</span></a></li><li id="n-aboutsite" class="mw-l'
#  b'ist-item"><a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and h'
#  b'ow it works"><span>About Wikipedia</span></a></li><li id="n-contactpage" cla'
#  b'ss="mw-list-item"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" tit'
#  b'le="How to contact Wikipedia"><span>Contact us</span></a></li>\n\t\t</u'
#  b'l>\n\t\t\n\t</div>\n</div>\n\n\t\n\t\n<div id="p-interaction" class="vector-'
#  b'menu mw-portlet mw-portlet-interaction"  >\n\t<div class="vector-menu-head'
#  b'ing">\n\t\tContribute\n\t</div>\n\t<div class="vector-menu-content">\n\t\t'
#  b'\n\t\t<ul class="vector-menu-content-list">\n\t\t\t\n\t\t\t<li id="n-help" '
#  b'class="mw-list-item"><a href="/wiki/Help:Contents" title="Guidance on how to'
#  b' use and edit Wikipedia"><span>Help</span></a></li><li id="n-introduction" c'
#  b'lass="mw-list-item"><a href="/wiki/Help:Introduction" title="Learn how to ed'
#  b'it Wikipedia"><span>Learn to edit</span></a></li><li id="n-portal" class="mw'
#  b'-list-item"><a href="/wiki/Wikipedia:Community_portal" title="The hub for ed'
#  b'itors"><span>Community portal</span></a></li><li id="n-recentchanges" class='
#  b'"mw-list-item"><a href="/wiki/Special:RecentChanges" title="A list of recent'
#  b' changes to Wikipedia [r]" accesskey="r"><span>Recent changes</span></a></li'
#  b'><li id="n-upload" class="mw-list-item"><a href="/wiki/Wikipedia:File_upload'
#  b'_wizard" title="Add images or other media for use on Wikipedia"><span>Upload'
#  b' file</span></a></li><li id="n-specialpages" class="mw-list-item"><a href="/'
#  b'wiki/Special:SpecialPages"><span>Special pages</span></a></li>\n\t\t</u'
#  b'l>\n\t\t\n\t</div>\n</div>\n\n</div>\n\n\t\t\t\t</div>\n\n\t</div>\n</div>'
#  b'\n\n\t\t</nav>\n\t\t\t\n<a href="/wiki/Main_Page" class="mw-logo">\n\t<img '
#  b'class="mw-logo-icon" src="/static/images/icons/wikipedia.png" alt="" aria-hi'
#  b'dden="true" height="50" width="50">\n\t<span class="mw-logo-container skin'
#  b'-invert">\n\t\t<img class="mw-logo-wordmark" alt="Wikipedia" src="/static/i'
#  b'mages/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; heigh'
#  b't: 1.125em;">\n\t\t<img class="mw-logo-tagline" alt="The Free Encyclopedia"'
#  b' src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" width="117" '
#  b'height="13" style="width: 7.3125em; height: 0.8125em;">\n\t</span>\n</a'
#  b'>\n\n\t\t</div>\n\t\t<div class="vector-header-end">\n\t\t\t\n<div id="p-sea'
#  b'rch" role="search" class="vector-search-box-vue  vector-search-box-collapses'
#  b' vector-search-box-show-thumbnail vector-search-box-auto-expand-width vector'
#  b'-search-box">\n\t<a href="/wiki/Special:Search" class="cdx-button cdx-butt'
#  b'on--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cd'
#  b'x-button--icon-only search-toggle" title="Search Wikipedia [f]" accesskey="f'
#  b'"><span class="vector-icon mw-ui-icon-search mw-ui-icon-wikimedia-search"></'
#  b'span>\n\n<span>Search</span>\n\t</a>\n\t<div class="vector-typeahead-searc'
#  b'h-container">\n\t\t<div class="cdx-typeahead-search cdx-typeahead-search--s'
#  b'how-thumbnail cdx-typeahead-search--auto-expand-width">\n\t\t\t<form action='
#  b'"/w/index.php" id="searchform" class="cdx-search-input cdx-search-input--has'
#  b'-end-button">\n\t\t\t\t<div id="simpleSearch" class="cdx-search-input__in'
#  b'put-wrapper"  data-search-loc="header-moved">\n\t\t\t\t\t<div class="cdx-t'
#  b'ext-input cdx-text-input--has-start-icon">\n\t\t\t\t\t\t<input\n\t\t\t\t'
#  b'\t\t\tclass="cdx-text-input__input mw-searchInput" autocomplete="off"\n\t'
#  b'\t\t\t\t\t\t type="search" name="search" placeholder="Search Wikipedia" ar'
#  b'ia-label="Search Wikipedia" autocapitalize="sentences" spellcheck="false" ti'
#  b'tle="Search Wikipedia [f]" accesskey="f" id="searchInput"\n\t\t\t\t\t\t'
#  b'\t>\n\t\t\t\t\t\t<span class="cdx-text-input__icon cdx-text-input__start-ico'
#  b'n"></span>\n\t\t\t\t\t</div>\n\t\t\t\t\t<input type="hidden" name="title" va'
#  b'lue="Special:Search">\n\t\t\t\t</div>\n\t\t\t\t<button class="cdx-button c'
#  b'dx-search-input__end-button">Search</button>\n\t\t\t</form>\n\t\t</div>'
#  b'\n\t</div>\n</div>\n\n\t\t\t<nav class="vector-user-links vector-user-links-'
#  b'wide" aria-label="Personal tools">\n\t<div class="vector-user-links-main">'
#  b'\n\t\n<div id="p-vector-user-menu-preferences" class="vector-menu mw-portle'
#  b't emptyPortlet"  >\n\t<div class="vector-menu-content">\n\t\t\n\t\t<ul class'
#  b'="vector-menu-content-list">\n\t\t\t\n\t\t\t\n\t\t</ul>\n\t\t\n\t</div>\n'
#  b'</div>\n\n\t\n<div id="p-vector-user-menu-userpage" class="vector-menu mw-po'
#  b'rtlet emptyPortlet"  >\n\t<div class="vector-menu-content">\n\t\t\n\t\t<ul c'
#  b'lass="vector-menu-content-list">\n\t\t\t\n\t\t\t\n\t\t</ul>\n\t\t\n\t</d'
#  b'iv>\n</div>\n\n\t<nav class="vector-appearance-landmark" aria-label="Appeara'
#  b'nce">\n\t\t\n<div id="vector-appearance-dropdown" class="vector-dropdown "  '
#  b'title="Change the appearance of the page&#039;s font size, width, and color"'
#  b' >\n\t<input type="checkbox" id="vector-appearance-dropdown-checkbox" role'
#  b'="button" aria-haspopup="true" data-event-name="ui.dropdown-vector-appearanc'
#  b'e-dropdown" class="vector-dropdown-checkbox "  aria-label="Appearance"  '
#  b'>\n\t<label id="vector-appearance-dropdown-label" for="vector-appearance-d'
#  b'ropdown-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-b'
#  b'utton cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--'
#  b'icon-only " aria-hidden="true"  ><span class="vector-icon mw-ui-icon-appeara'
#  b'nce mw-ui-icon-wikimedia-appearance"></span>\n\n<span class="vector-dropdo'
#  b'wn-label-text">Appearance</span>\n\t</label>\n\t<div class="vector-dropdown-'
#  b'content">\n\n\n\t\t\t<div id="vector-appearance-unpinned-container" class='
#  b'"vector-unpinned-container">\n\t\t\t\t\n\t\t\t</div>\n\t\t\n\t</div>\n</div'
#  b'>\n\n\t</nav>\n\t\n<div id="p-vector-user-menu-notifications" class="vecto'
#  b'r-menu mw-portlet emptyPortlet"  >\n\t<div class="vector-menu-content"'
#  b'>\n\t\t\n\t\t<ul class="vector-menu-content-list">\n\t\t\t\n\t\t\t\n\t\t<'
#  b'/ul>\n\t\t\n\t</div>\n</div>\n\n\t\n<div id="p-vector-user-menu-overflow" '
#  b'class="vector-menu mw-portlet"  >\n\t<div class="vector-menu-content">'
#  b'\n\t\t\n\t\t<ul class="vector-menu-content-list">\n\t\t\t<li id="pt-sitesu'
#  b'pport-2" class="user-links-collapsible-item mw-list-item user-links-collapsi'
#  b'ble-item"><a data-mw="interface" href="https://donate.wikimedia.org/?wmf_sou'
#  b'rce=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;usel'
#  b'ang=en" class=""><span>Donate</span></a>\n</li>\n<li id="pt-createaccount-'
#  b'2" class="user-links-collapsible-item mw-list-item user-links-collapsible-it'
#  b'em"><a data-mw="interface" href="/w/index.php?title=Special:CreateAccount&am'
#  b'p;returnto=List+of+United+States+cities+by+population" title="You are encour'
#  b'aged to create an account and log in; however, it is not mandatory" class=""'
#  b'><span>Create account</span></a>\n</li>\n<li id="pt-login-2" class="user-l'
#  b'inks-collapsible-item mw-list-item user-links-collapsible-item"><a data-mw="'
#  b'interface" href="/w/index.php?title=Special:UserLogin&amp;returnto=List+of+U'
#  b'nited+States+cities+by+population" title="You&#039;re encouraged to log in; '
#  b'however, it&#039;s not mandatory. [o]" accesskey="o" class=""><span>Log in</'
#  b'span></a>\n</li>\n\n\t\t\t\n\t\t</ul>\n\t\t\n\t</div>\n</div>\n\n\t</div>\n'
#  b'\t\n<div id="vector-user-links-dropdown" class="vector-dropdown vector-use'
#  b'r-menu vector-button-flush-right vector-user-menu-logged-out"  title="Log in'
#  b' and more options" >\n\t<input type="checkbox" id="vector-user-links-dropd'
#  b'own-checkbox" role="button" aria-haspopup="true" data-event-name="ui.dropdow'
#  b'n-vector-user-links-dropdown" class="vector-dropdown-checkbox "  aria-label='
#  b'"Personal tools"  >\n\t<label id="vector-user-links-dropdown-label" for="v'
#  b'ector-user-links-dropdown-checkbox" class="vector-dropdown-label cdx-button '
#  b'cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-'
#  b'quiet cdx-button--icon-only " aria-hidden="true"  ><span class="vector-icon '
#  b'mw-ui-icon-ellipsis mw-ui-icon-wikimedia-ellipsis"></span>\n\n<span class='
#  b'"vector-dropdown-label-text">Personal tools</span>\n\t</label>\n\t<div class'
#  b'="vector-dropdown-content">\n\n\n\t\t\n<div id="p-personal" class="vector-'
#  b'menu mw-portlet mw-portlet-personal user-links-collapsible-item"  title="Use'
#  b'r menu" >\n\t<div class="vector-menu-content">\n\t\t\n\t\t<ul class="vector-'
#  b'menu-content-list">\n\t\t\t\n\t\t\t<li id="pt-sitesupport" class="user-links'
#  b'-collapsible-item mw-list-item"><a href="https://donate.wikimedia.org/?wmf_s'
#  b'ource=donate&amp;wmf_medium=sidebar&amp;wmf_campaign=en.wikipedia.org&amp;us'
#  b'elang=en"><span>Donate</span></a></li><li id="pt-createaccount" class="user-'
#  b'links-collapsible-item mw-list-item"><a href="/w/index.php?title=Special:Cre'
#  b'ateAccount&amp;returnto=List+of+United+States+cities+by+population" title="Y'
#  b'ou are encouraged to create an account and log in; however, it is not mandat'
#  b'ory"><span class="vector-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAd'
#  b'd"></span> <span>Create account</span></a></li><li id="pt-login" class="user'
#  b'-links-collapsible-item mw-list-item"><a href="/w/index.php?title=Special:Us'
#  b'erLogin&amp;returnto=List+of+United+States+cities+by+population" title="You&'
#  b'#039;re encouraged to log in; however, it&#039;s not mandatory. [o]" accessk'
#  b'ey="o"><span class="vector-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn"'
#  b'></span> <span>Log in</span></a></li>\n\t\t</ul>\n\t\t\n\t</div>\n</div>\n'
#  b'\n<div id="p-user-menu-anon-editor" class="vector-menu mw-portlet mw-port'
#  b'let-user-menu-anon-editor"  >\n\t<div class="vector-menu-heading">\n\t\tP'
#  b'ages for logged out editors <a href="/wiki/Help:Introduction" aria-label="Le'
#  b'arn more about editing"><span>learn more</span></a>\n\t</div>\n\t<div class='
#  b'"vector-menu-content">\n\t\t\n\t\t<ul class="vector-menu-content-list"'
#  b'>\n\t\t\t\n\t\t\t<li id="pt-anoncontribs" class="mw-list-item"><a href="/wik'
#  b'i/Special:MyContributions" title="A list of edits made from this IP address '
#  b'[y]" accesskey="y"><span>Contributions</span></a></li><li id="pt-anontalk" c'
#  b'lass="mw-list-item"><a href="/wiki/Special:MyTalk" title="Discussion about e'
#  b'dits from this IP address [n]" accesskey="n"><span>Talk</span></a></li>\n'
#  b'\t\t</ul>\n\t\t\n\t</div>\n</div>\n\n\t\n\t</div>\n</div>\n\n</nav>\n\n\t\t<'
#  b'/div>\n\t</header>\n</div>\n<div class="mw-page-container">\n\t<div class='
#  b'"mw-page-container-inner">\n\t\t<div class="vector-sitenotice-container'
#  b'">\n\t\t\t<div id="siteNotice"><!-- CentralNotice --></div>\n\t\t</div>'
#  b'\n\t\t<div class="vector-column-start">\n\t\t\t<div class="vector-main-menu'
#  b'-container">\n\t\t<div id="mw-navigation">\n\t\t\t<nav id="mw-panel" class='
#  b'"vector-main-menu-landmark" aria-label="Site">\n\t\t\t\t<div id="vector-m'
#  b'ain-menu-pinned-container" class="vector-pinned-container">\n\t\t\t\t'
#  b'\n\t\t\t\t</div>\n\t\t</nav>\n\t\t</div>\n\t</div>\n\t<div class="vector-st'
#  b'icky-pinned-container">\n\t\t\t\t<nav id="mw-panel-toc" aria-label="Conte'
#  b'nts" data-event-name="ui.sidebar-toc" class="mw-table-of-contents-container '
#  b'vector-toc-landmark">\n\t\t\t\t\t<div id="vector-toc-pinned-container" cla'
#  b'ss="vector-pinned-container">\n\t\t\t\t\t<div id="vector-toc" class="vecto'
#  b'r-toc vector-pinnable-element">\n\t<div\n\tclass="vector-pinnable-header vec'
#  b'tor-toc-pinnable-header vector-pinnable-header-pinned"\n\tdata-feature-nam'
#  b'e="toc-pinned"\n\tdata-pinnable-element-id="vector-toc"\n\t\n\t\n>\n\t<h2'
#  b' class="vector-pinnable-header-label">Contents</h2>\n\t<button class="vect'
#  b'or-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-eve'
#  b'nt-name="pinnable-header.vector-toc.pin">move to sidebar</button>\n\t<butt'
#  b'on class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-'
#  b'button" data-event-name="pinnable-header.vector-toc.unpin">hide</button>'
#  b'\n</div>\n\n\n\t<ul class="vector-toc-contents" id="mw-panel-toc-list">\n\t'
#  b'\t<li id="toc-mw-content-text"\n\t\t\tclass="vector-toc-list-item vector-'
#  b'toc-level-1">\n\t\t\t<a href="#" class="vector-toc-link">\n\t\t\t\t<div c'
#  b'lass="vector-toc-text">(Top)</div>\n\t\t\t</a>\n\t\t</li>\n\t\t<li id="toc'
#  b'-50_states_and_Washington,_D.C."\n\t\tclass="vector-toc-list-item vector-to'
#  b'c-level-1 vector-toc-list-item-expanded">\n\t\t<a class="vector-toc-link" h'
#  b'ref="#50_states_and_Washington,_D.C.">\n\t\t\t<div class="vector-toc-tex'
#  b't">\n\t\t\t\t<span class="vector-toc-numb">1</span>\n\t\t\t\t<span>50 stat'
#  b'es and Washington, D.C.</span>\n\t\t\t</div>\n\t\t</a>\n\t\t\n\t\t\t<butto'
#  b'n aria-controls="toc-50_states_and_Washington,_D.C.-sublist" class="cdx-butt'
#  b'on cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">\n\t\t'
#  b'\t\t<span class="vector-icon mw-ui-icon-wikimedia-expand"></span>\n\t\t\t\t'
#  b'<span>Toggle 50 states and Washington, D.C. subsection</span>\n\t\t\t</butto'
#  b'n>\n\t\t\n\t\t<ul id="toc-50_states_and_Washington,_D.C.-sublist" class="v'
#  b'ector-toc-list">\n\t\t\t<li id="toc-Distribution"\n\t\t\tclass="vector-toc-l'
#  b'ist-item vector-toc-level-2">\n\t\t\t<a class="vector-toc-link" href="#Distr'
#  b'ibution">\n\t\t\t\t<div class="vector-toc-text">\n\t\t\t\t\t<span class="ve'
#  b'ctor-toc-numb">1.1</span>\n\t\t\t\t\t<span>Distribution</span>\n\t\t\t\t</d'
#  b'iv>\n\t\t\t</a>\n\t\t\t\n\t\t\t<ul id="toc-Distribution-sublist" class="vect'
#  b'or-toc-list">\n\t\t\t</ul>\n\t\t</li>\n\t\t<li id="toc-Gallery"\n\t\t\tcla'
#  b'ss="vector-toc-list-item vector-toc-level-2">\n\t\t\t<a class="vector-toc-li'
#  b'nk" href="#Gallery">\n\t\t\t\t<div class="vector-toc-text">\n\t\t\t\t\t<spa'
#  b'n class="vector-toc-numb">1.2</span>\n\t\t\t\t\t<span>Gallery</span>\n\t'
#  b'\t\t\t</div>\n\t\t\t</a>\n\t\t\t\n\t\t\t<ul id="toc-Gallery-sublist" class='
#  b'"vector-toc-list">\n\t\t\t</ul>\n\t\t</li>\n\t</ul>\n\t</li>\n\t<li id="t'
#  b'oc-Puerto_Rico"\n\t\tclass="vector-toc-list-item vector-toc-level-1 vector-'
#  b'toc-list-item-expanded">\n\t\t<a class="vector-toc-link" href="#Puerto_Rico'
#  b'">\n\t\t\t<div class="vector-toc-text">\n\t\t\t\t<span class="vector-toc-'
#  b'numb">2</span>\n\t\t\t\t<span>Puerto Rico</span>\n\t\t\t</div>\n\t\t</a>'
#  b'\n\t\t\n\t\t<ul id="toc-Puerto_Rico-sublist" class="vector-toc-list">\n'
#  b'\t\t</ul>\n\t</li>\n\t<li id="toc-Other_U.S._territories"\n\t\tclass="vec'
#  b'tor-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded">\n\t\t<'
#  b'a class="vector-toc-link" href="#Other_U.S._territories">\n\t\t\t<div class='
#  b'"vector-toc-text">\n\t\t\t\t<span class="vector-toc-numb">3</span>\n\t\t'
#  b'\t\t<span>Other U.S. territories</span>\n\t\t\t</div>\n\t\t</a>\n\t\t\n\t\t'
#  b'<ul id="toc-Other_U.S._territories-sublist" class="vector-toc-list">\n\t\t<'
#  b'/ul>\n\t</li>\n\t<li id="toc-Census-designated_places"\n\t\tclass="vector-t'
#  b'oc-list-item vector-toc-level-1 vector-toc-list-item-expanded">\n\t\t<a cla'
#  b'ss="vector-toc-link" href="#Census-designated_places">\n\t\t\t<div class="ve'
#  b'ctor-toc-text">\n\t\t\t\t<span class="vector-toc-numb">4</span>\n\t\t\t\t<'
#  b'span>Census-designated places</span>\n\t\t\t</div>\n\t\t</a>\n\t\t\n\t\t<'
#  b'ul id="toc-Census-designated_places-sublist" class="vector-toc-list">\n\t\t'
#  b'</ul>\n\t</li>\n\t<li id="toc-Cities_formerly_over_100,000_people"\n\t\tcla'
#  b'ss="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expande'
#  b'd">\n\t\t<a class="vector-toc-link" href="#Cities_formerly_over_100,000_peo'
#  b'ple">\n\t\t\t<div class="vector-toc-text">\n\t\t\t\t<span class="vector-t'
#  b'oc-numb">5</span>\n\t\t\t\t<span>Cities formerly over 100,000 people</spa'
#  b'n>\n\t\t\t</div>\n\t\t</a>\n\t\t\n\t\t<ul id="toc-Cities_formerly_over_10'
#  b'0,000_people-sublist" class="vector-toc-list">\n\t\t</ul>\n\t</li>\n\t<li i'
#  b'd="toc-Locations_of_50_most_populous_cities"\n\t\tclass="vector-toc-list-it'
#  b'em vector-toc-level-1 vector-toc-list-item-expanded">\n\t\t<a class="vector'
#  b'-toc-link" href="#Locations_of_50_most_populous_cities">\n\t\t\t<div class="'
#  b'vector-toc-text">\n\t\t\t\t<span class="vector-toc-numb">6</span>\n\t\t\t'
#  b'\t<span>Locations of 50 most populous cities</span>\n\t\t\t</div>\n\t\t<'
#  b'/a>\n\t\t\n\t\t<ul id="toc-Locations_of_50_most_populous_cities-sublist" c'
#  b'lass="vector-toc-list">\n\t\t</ul>\n\t</li>\n\t<li id="toc-See_also"\n\t\t'
#  b'class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded'
#  b'">\n\t\t<a class="vector-toc-link" href="#See_also">\n\t\t\t<div class="vec'
#  b'tor-toc-text">\n\t\t\t\t<span class="vector-toc-numb">7</span>\n\t\t\t\t<s'
#  b'pan>See also</span>\n\t\t\t</div>\n\t\t</a>\n\t\t\n\t\t<ul id="toc-See_al'
#  b'so-sublist" class="vector-toc-list">\n\t\t</ul>\n\t</li>\n\t<li id="toc-Not'
#  b'es"\n\t\tclass="vector-toc-list-item vector-toc-level-1 vector-toc-list-ite'
#  b'm-expanded">\n\t\t<a class="vector-toc-link" href="#Notes">\n\t\t\t<div cla'
#  b'ss="vector-toc-text">\n\t\t\t\t<span class="vector-toc-numb">8</span>'
#  b'\n\t\t\t\t<span>Notes</span>\n\t\t\t</div>\n\t\t</a>\n\t\t\n\t\t<ul id="to'
#  b'c-Notes-sublist" class="vector-toc-list">\n\t\t</ul>\n\t</li>\n\t<li id="to'
#  b'c-References"\n\t\tclass="vector-toc-list-item vector-toc-level-1 vector-to'
#  b'c-list-item-expanded">\n\t\t<a class="vector-toc-link" href="#References">\n'
#  b'\t\t\t<div class="vector-toc-text">\n\t\t\t\t<span class="vector-toc-numb">9'
#  b'</span>\n\t\t\t\t<span>References</span>\n\t\t\t</div>\n\t\t</a>\n\t\t\n'
#  b'\t\t<ul id="toc-References-sublist" class="vector-toc-list">\n\t\t</ul>\n\t'
#  b'</li>\n\t<li id="toc-External_links"\n\t\tclass="vector-toc-list-item vec'
#  b'tor-toc-level-1 vector-toc-list-item-expanded">\n\t\t<a class="vector-toc-l'
#  b'ink" href="#External_links">\n\t\t\t<div class="vector-toc-text">\n\t\t'
#  b'\t\t<span class="vector-toc-numb">10</span>\n\t\t\t\t<span>External links</'
#  b'span>\n\t\t\t</div>\n\t\t</a>\n\t\t\n\t\t<ul id="toc-External_links-subli'
#  b'st" class="vector-toc-list">\n\t\t</ul>\n\t</li>\n</ul>\n</div>\n\n\t\t'
#  b'\t\t\t</div>\n\t\t</nav>\n\t\t\t</div>\n\t\t</div>\n\t\t<div class="mw-conte'
#  b'nt-container">\n\t\t\t<main id="content" class="mw-body">\n\t\t\t\t<heade'
#  b'r class="mw-body-header vector-page-titlebar no-font-mode-scale">\n\t\t'
#  b'\t\t\t<nav aria-label="Contents" class="vector-toc-landmark">\n\t\t\t\t\t'
#  b'\t\n<div id="vector-page-titlebar-toc" class="vector-dropdown vector-page-'
#  b'titlebar-toc vector-button-flush-left"  title="Table of Contents" >\n\t<in'
#  b'put type="checkbox" id="vector-page-titlebar-toc-checkbox" role="button" ari'
#  b'a-haspopup="true" data-event-name="ui.dropdown-vector-page-titlebar-toc" cla'
#  b'ss="vector-dropdown-checkbox "  aria-label="Toggle the table of contents"  >'
#  b'\n\t<label id="vector-page-titlebar-toc-label" for="vector-page-titlebar-t'
#  b'oc-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-button'
#  b' cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-'
#  b'only " aria-hidden="true"  ><span class="vector-icon mw-ui-icon-listBullet m'
#  b'w-ui-icon-wikimedia-listBullet"></span>\n\n<span class="vector-dropdown-la'
#  b'bel-text">Toggle the table of contents</span>\n\t</label>\n\t<div class="vec'
#  b'tor-dropdown-content">\n\n\n\t\t\t\t\t\t\t<div id="vector-page-titlebar-to'
#  b'c-unpinned-container" class="vector-unpinned-container">\n\t\t\t</div>\n\t'
#  b'\t\n\t</div>\n</div>\n\n\t\t\t\t\t</nav>\n\t\t\t\t\t<h1 id="firstHeading"'
#  b' class="firstHeading mw-first-heading"><span class="mw-page-title-main">List'
#  b' of United States cities by population</span></h1>\n\t\t\t\t\t\t\t\n<div '
#  b'id="p-lang-btn" class="vector-dropdown mw-portlet mw-portlet-lang"  >\n\t<'
#  b'input type="checkbox" id="p-lang-btn-checkbox" role="button" aria-haspopup="'
#  b'true" data-event-name="ui.dropdown-p-lang-btn" class="vector-dropdown-checkb'
#  b'ox mw-interlanguage-selector" aria-label="Go to an article in another langua'
#  b'ge. Available in 71 languages"   >\n\t<label id="p-lang-btn-label" for="p-'
#  b'lang-btn-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake-'
#  b'button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button-'
#  b'-action-progressive mw-portlet-lang-heading-71" aria-hidden="true"  ><span c'
#  b'lass="vector-icon mw-ui-icon-language-progressive mw-ui-icon-wikimedia-langu'
#  b'age-progressive"></span>\n\n<span class="vector-dropdown-label-text">71 la'
#  b'nguages</span>\n\t</label>\n\t<div class="vector-dropdown-content">\n\n\t\t<'
#  b'div class="vector-menu-content">\n\t\t\t\n\t\t\t<ul class="vector-menu-conte'
#  b'nt-list">\n\t\t\t\t\n\t\t\t\t<li class="interlanguage-link interwiki-af mw'
#  b'-list-item"><a href="https://af.wikipedia.org/wiki/Lys_van_nedersettings_in_'
#  b'die_Verenigde_State_van_Amerika" title="Lys van nedersettings in die Verenig'
#  b'de State van Amerika \xe2\x80\x93 Afrikaans" lang="af" hreflang="af" data'
#  b'-title="Lys van nedersettings in die Verenigde State van Amerika" data-langu'
#  b'age-autonym="Afrikaans" data-language-local-name="Afrikaans" class="interlan'
#  b'guage-link-target"><span>Afrikaans</span></a></li><li class="interlanguage-l'
#  b'ink interwiki-ang mw-list-item"><a href="https://ang.wikipedia.org/wiki/Byri'
#  b'g_%C3%BE%C4%81ra_Ge%C4%81ndena_R%C4%ABca" title="Byrig \xc3\xbe\xc4\x81ra Ge'
#  b'\xc4\x81ndena R\xc4\xabca \xe2\x80\x93 Old English" lang="ang" hreflang="'
#  b'ang" data-title="Byrig \xc3\xbe\xc4\x81ra Ge\xc4\x81ndena R\xc4\xabca" data-'
#  b'language-autonym="\xc3\x86nglisc" data-language-local-name="Old English" c'
#  b'lass="interlanguage-link-target"><span>\xc3\x86nglisc</span></a></li><li c'
#  b'lass="interlanguage-link interwiki-ar mw-list-item"><a href="https://ar.wiki'
#  b'pedia.org/wiki/%D9%82%D8%A7%D8%A6%D9%85%D8%A9_%D9%85%D8%AF%D9%86_%D8%A7%D9%8'
#  b'4%D9%88%D9%84%D8%A7%D9%8A%D8%A7%D8%AA_%D8%A7%D9%84%D9%85%D8%AA%D8%AD%D8%AF%D'
#  b'8%A9_%D8%AD%D8%B3%D8%A8_%D8%B9%D8%AF%D8%AF_%D8%A7%D9%84%D8%B3%D9%83%D8%A7%D9'
#  b'%86" title="\xd9\x82\xd8\xa7\xd8\xa6\xd9\x85\xd8\xa9 \xd9\x85\xd8\xaf\xd9'
#  b'\x86 \xd8\xa7\xd9\x84\xd9\x88\xd9\x84\xd8\xa7\xd9\x8a\xd8\xa7\xd8\xaa \xd8'
#  b'\xa7\xd9\x84\xd9\x85\xd8\xaa\xd8\xad\xd8\xaf\xd8\xa9 \xd8\xad'
xd0\xb5\xd0\xbb\xd0\xb5\xd0\xbd\xd0\xb8\xd0\xb5" data-langu'
#  b'age-autonym="\xd0\x91\xd1\x8a\xd0\xbb\xd0\xb3\xd0\xb0\xd1\x80\xd1\x81\xd0'
#  b'\xba\xd0\xb8" data-language-local-name="Bulgarian" class="interlanguage-l'
#  b'ink-target"><span>\xd0\x91\xd1\x8a\xd0\xbb\xd0\xb3\xd0\xb0\xd1\x80\xd1\x81'
#  b'\xd0\xba\xd0\xb8</span></a></li><li class="interlanguage-link interwiki-bar '
#  b'mw-list-item"><a href="https://bar.wikipedia.org/wiki/St%C3%A4dt_in_da_USA" '
#  b'title="St\xc3\xa4dt in da USA \xe2\x80\x93 Bavarian" lang="bar" hreflang="b'
#  b'ar" data-title="St\xc3\xa4dt in da USA" data-language-autonym="Boarisch" d'
#  b'ata-language-local-name="Bavarian" class="interlanguage-link-target"><span>B'
#  b'oarisch</span></a></li><li class="interlanguage-link interwiki-bs mw-list-it'
#  b'em"><a href="https://bs.wikipedia.org/wiki/Spisak_najve%C4%87ih_mjesta_u_Sje'
#  b'dinjenim_Ameri%C4%8Dkim_Dr%C5%BEavama" title="Spisak najve\xc4\x87ih mjest'
#  b'a u Sjedinjenim Ameri\xc4\x8dkim Dr\xc5\xbeavama \xe2\x80\x93 Bosnian" la'
#  b'ng="bs" hreflang="bs" data-title="Spisak najve\xc4\x87ih mjesta u Sjedinje'
#  b'nim Ameri\xc4\x8dkim Dr\xc5\xbeavama" data-language-autonym="Bosanski" data-'
#  b'language-local-name="Bosnian" class="interlanguage-link-target"><span>Bosans'
#  b'ki</span></a></li><li class="interlanguage-link interwiki-ca mw-list-item"><'
#  b'a href="https://ca.wikipedia.org/wiki/Llista_de_ciutats_dels_Estats_Units_pe'
#  b'r_poblaci%C3%B3" title="Llista de ciutats dels Estats Units per poblaci\xc3'
#  b'\xb3 \xe2\x80\x93 Catalan" lang="ca" hreflang="ca" data-title="Llista de ciu'
#  b'tats dels Estats Units per poblaci\xc3\xb3" data-language-autonym="Cat'
#  b'al\xc3\xa0" data-language-local-name="Catalan" class="interlanguage-link-t'
#  b'arget"><span>Catal\xc3\xa0</span></a></li><li class="interlanguage-link in'
#  b'terwiki-cs badge-Q70893996 mw-list-item" title=""><a href="https://cs.wikipe'
#  b'dia.org/wiki/Seznam_m%C4%9Bst_USA_podle_po%C4%8Dtu_obyvatel" title="Seznam m'
#  b'\xc4\x9bst USA podle po\xc4\x8dtu obyvatel \xe2\x80\x93 Czech" lang="cs" '
#  b'hreflang="cs" data-title="Seznam m\xc4\x9bst USA podle po\xc4\x8dtu obyvatel'
#  b'" data-language-autonym="\xc4\x8ce\xc5\xa1tina" data-language-local-name="Cz'
#  b'ech" class="interlanguage-link-target"><span>\xc4\x8ce\xc5\xa1tina</span></a'
#  b'></li><li class="interlanguage-link interwiki-da mw-list-item"><a href="http'
#  b's://da.wikipedia.org/wiki/USA%27s_st%C3%B8rste_byer" title="USA&#039;s s'
#  b't\xc3\xb8rste byer \xe2\x80\x93 Danish" lang="da" hreflang="da" data-title='
#  b'"USA&#039;s st\xc3\xb8rste byer" data-language-autonym="Dansk" data-langua'
#  b'ge-local-name="Danish" class="interlanguage-link-target"><span>Dansk</span><'
#  b'/a></li><li class="interlanguage-link interwiki-de mw-list-item"><a href
#  b'em"><a href="https://eo.wikipedia.org/wiki/Listo_de_urboj_de_Usono" title="L'
# ...
#  b'Category:Geographic coordinate lists">Geographic coordinate lists</a></li><l'
#  b'i><a href="/wiki/Category:Articles_with_Geo" title="Category:Articles with G'
#  b'eo">Articles with Geo</a></li><li><a href="/wiki/Category:Pages_using_gadget'
#  b'_WikiMiniAtlas" title="Category:Pages using gadget WikiMiniAtlas">Pages usin'
#  b'g gadget WikiMiniAtlas</a></li><li><a href="/wiki/Category:Pages_using_galle'
#  b'ry_without_a_media_namespace_prefix" title="Category:Pages using gallery wit'
#  b'hout a media namespace prefix">Pages using gallery without a media namespace'
#  b' prefix</a></li><li><a href="/wiki/Category:Articles_containing_Spanish-lang'
#  b'uage_text" title="Category:Articles containing Spanish-language text">Articl'
#  b'es containing Spanish-language text</a></li><li><a href="/wiki/Category:All_'
#  b'articles_with_unsourced_statements" title="Category:All articles with unsour'
#  b'ced statements">All articles with unsourced statements</a></li><li><a href="'
#  b'/wiki/Category:Articles_with_unsourced_statements_from_May_2025" title="Cate'
#  b'gory:Articles with unsourced statements from May 2025">Articles with unsourc'
#  b'ed statements from May 2025</a></li><li><a href="/wiki/Category:Pages_using_'
#  b'Sister_project_links_with_wikidata_namespace_mismatch" title="Category:Pages'
#  b' using Sister project links with wikidata namespace mismatch">Pages using Si'
#  b'ster project links with wikidata namespace mismatch</a></li><li><a href="/wi'
#  b'ki/Category:Pages_using_Sister_project_links_with_wikidata_mismatch" title="'
#  b'Category:Pages using Sister project links with wikidata mismatch">Pages usin'
#  b'g Sister project links with wikidata mismatch</a></li><li><a href="/wiki/Cat'
#  b'egory:Pages_using_Sister_project_links_with_default_search" title="Category:'
#  b'Pages using Sister project links with default search">Pages using Sister pro'
#  b'ject links with default search</a></li><li><a href="/wiki/Category:Featured_'
#  b'lists" title="Category:Featured lists">Featured lists</a></li></ul></div></d'
#  b'iv>\n\t\t\t\t</div>\n\t\t\t</main>\n\t\t\t\n\t\t</div>\n\t\t<div class="mw-'
#  b'footer-container">\n\t\t\t\n<footer id="footer" class="mw-footer" >\n\t<ul '
#  b'id="footer-info">\n\t<li id="footer-info-lastmod"> This page was last edit'
#  b'ed on 9 September 2025, at 00:44<span class="anonymous-show">&#160;(UTC)</sp'
#  b'an>.</li>\n\t<li id="footer-info-copyright">Text is available under the <a'
#  b' href="/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4'
#  b'.0_International_License" title="Wikipedia:Text of the Creative Commons Attr'
#  b'ibution-ShareAlike 4.0 International License">Creative Commons Attribution-S'
#  b'hareAlike 4.0 License</a>;\nadditional terms may apply. By using this sit'
#  b'e, you agree to the <a href="https://foundation.wikimedia.org/wiki/Special:M'
#  b'yLanguage/Policy:Terms_of_Use" class="extiw" title="foundation:Special:MyLan'
#  b'guage/Policy:Terms of Use">Terms of Use</a> and <a href="https://foundation.'
#  b'wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy" class="extiw" t'
#  b'itle="foundation:Special:MyLanguage/Policy:Privacy policy">Privacy Policy</a'
#  b'>. Wikipedia\xc2\xae is a registered trademark of the <a rel="nofollow" cl'
#  b'ass="external text" href="https://wikimediafoundation.org/">Wikimedia Founda'
#  b'tion, Inc.</a>, a non-profit organization.</li>\n</ul>\n\n\t<ul id="footer-p'
#  b'laces">\n\t<li id="footer-places-privacy"><a href="https://foundation.wiki'
#  b'media.org/wiki/Special:MyLanguage/Policy:Privacy_policy">Privacy policy</a><'
#  b'/li>\n\t<li id="footer-places-about"><a href="/wiki/Wikipedia:About">About'
#  b' Wikipedia</a></li>\n\t<li id="footer-places-disclaimers"><a href="/wiki/W'
#  b'ikipedia:General_disclaimer">Disclaimers</a></li>\n\t<li id="footer-places'
#  b'-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wik'
#  b'ipedia</a></li>\n\t<li id="footer-places-wm-codeofconduct"><a href="https:'
#  b'//foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_'
#  b'Conduct">Code of Conduct</a></li>\n\t<li id="footer-places-developers"><a '
#  b'href="https://developer.wikimedia.org">Developers</a></li>\n\t<li id="foot'
#  b'er-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org'
#  b'">Statistics</a></li>\n\t<li id="footer-places-cookiestatement"><a href="h'
#  b'ttps://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statem'
#  b'ent">Cookie statement</a></li>\n\t<li id="footer-places-mobileview"><a hre'
#  b'f="//en.wikipedia.org/w/index.php?title=List_of_United_States_cities_by_popu'
#  b'lation&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirec'
#  b'tToggle">Mobile view</a></li>\n</ul>\n\n\t<ul id="footer-icons" class="nopri'
#  b'nt">\n\t<li id="footer-copyrightico"><a href="https://www.wikimedia.org/" '
#  b'class="cdx-button cdx-button--fake-button cdx-button--size-large cdx-button-'
#  b'-fake-button--enabled"><picture><source media="(min-width: 500px)" srcset="/'
#  b'static/images/footer/wikimedia-button.svg" width="84" height="29"><img src="'
#  b'/static/images/footer/wikimedia.svg" width="25" height="25" alt="Wikimedia F'
#  b'oundation" lang="en" loading="lazy"></picture></a></li>\n\t<li id="footer-'
#  b'poweredbyico"><a href="https://www.mediawiki.org/" class="cdx-button cdx-but'
#  b'ton--fake-button cdx-button--size-large cdx-button--fake-button--enabled"><p'
#  b'icture><source media="(min-width: 500px)" srcset="/w/resources/assets/powere'
#  b'dby_mediawiki.svg" width="88" height="31"><img src="/w/resources/assets/medi'
#  b'awiki_compact.svg" alt="Powered by MediaWiki" lang="en" width="25" height="2'
#  b'5" loading="lazy"></picture></a></li>\n</ul>\n\n</footer>\n\n\t\t</div>'
#  b'\n\t</div> \n</div> \n<div class="vector-header-container vector-sticky-head'
#  b'er-container no-font-mode-scale">\n\t<div id="vector-sticky-header" class='
#  b'"vector-sticky-header">\n\t\t<div class="vector-sticky-header-start">\n\t'
#  b'\t\t<div class="vector-sticky-header-icon-start vector-button-flush-left v'
#  b'ector-button-flush-right" aria-hidden="true">\n\t\t\t\t<button class="cdx'
#  b'-button cdx-button--weight-quiet cdx-button--icon-only vector-sticky-header-'
#  b'search-toggle" tabindex="-1" data-event-name="ui.vector-sticky-search-form.i'
#  b'con"><span class="vector-icon mw-ui-icon-search mw-ui-icon-wikimedia-search"'
#  b'></span>\n\n<span>Search</span>\n\t\t\t</button>\n\t\t</div>\n\t\t\t\n\t\t<d'
#  b'iv role="search" class="vector-search-box-vue  vector-search-box-show-thumbn'
#  b'ail vector-search-box">\n\t\t\t<div class="vector-typeahead-search-container'
#  b'">\n\t\t\t\t<div class="cdx-typeahead-search cdx-typeahead-search--show-t'
#  b'humbnail">\n\t\t\t\t\t<form action="/w/index.php" id="vector-sticky-search'
#  b'-form" class="cdx-search-input cdx-search-input--has-end-button">\n\t\t'
#  b'\t\t\t\t<div  class="cdx-search-input__input-wrapper"  data-search-loc="head'
#  b'er-moved">\n\t\t\t\t\t\t\t<div class="cdx-text-input cdx-text-input--has-sta'
#  b'rt-icon">\n\t\t\t\t\t\t\t\t<input\n\t\t\t\t\t\t\t\t\tclass="cdx-text-input_'
#  b'_input mw-searchInput" autocomplete="off"\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t'
#  b'\t\t\t\t\ttype="search" name="search" placeholder="Search Wikipedia">'
#  b'\n\t\t\t\t\t\t\t\t<span class="cdx-text-input__icon cdx-text-input__start'
#  b'-icon"></span>\n\t\t\t\t\t\t\t</div>\n\t\t\t\t\t\t\t<input type="hidden" nam'
#  b'e="title" value="Special:Search">\n\t\t\t\t\t\t</div>\n\t\t\t\t\t\t<button'
#  b' class="cdx-button cdx-search-input__end-button">Search</button>\n\t\t\t'
#  b'\t\t</form>\n\t\t\t\t</div>\n\t\t\t</div>\n\t\t</div>\n\t\t<div class="ve'
#  b'ctor-sticky-header-context-bar">\n\t\t\t\t<nav aria-label="Contents" clas'
#  b's="vector-toc-landmark">\n\t\t\t\t\t\t\n\t\t\t\t\t<div id="vector-sticky-'
#  b'header-toc" class="vector-dropdown mw-portlet mw-portlet-sticky-header-toc v'
#  b'ector-sticky-header-toc vector-button-flush-left"  >\n\t\t\t\t\t\t<input ty'
#  b'pe="checkbox" id="vector-sticky-header-toc-checkbox" role="button" aria-hasp'
#  b'opup="true" data-event-name="ui.dropdown-vector-sticky-header-toc" class="ve'
#  b'ctor-dropdown-checkbox "  aria-label="Toggle the table of contents"  >\n\t'
#  b'\t\t\t\t\t<label id="vector-sticky-header-toc-label" for="vector-sticky-h'
#  b'eader-toc-checkbox" class="vector-dropdown-label cdx-button cdx-button--fake'
#  b'-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button'
#  b'--icon-only " aria-hidden="true"  ><span class="vector-icon mw-ui-icon-listB'
#  b'ullet mw-ui-icon-wikimedia-listBullet"></span>\n\n<span class="vector-drop'
#  b'down-label-text">Toggle the table of contents</span>\n\t\t\t\t\t\t</label>\n'
#  b'\t\t\t\t\t\t<div class="vector-dropdown-content">\n\t\t\t\t\t\n\t\t\t\t\t\t'
#  b'<div id="vector-sticky-header-toc-unpinned-container" class="vector-unpinned'
#  b'-container">\n\t\t\t\t\t\t</div>\n\t\t\t\t\t\n\t\t\t\t\t\t</div>\n\t\t\t'
#  b'\t\t</div>\n\t\t\t</nav>\n\t\t\t\t<div class="vector-sticky-header-context-'
#  b'bar-primary" aria-hidden="true" ><span class="mw-page-title-main">List of Un'
#  b'ited States cities by population</span></div>\n\t\t\t</div>\n\t\t</div>'
#  b'\n\t\t<div class="vector-sticky-header-end" aria-hidden="true">\n\t\t\t<div'
#  b' class="vector-sticky-header-icons">\n\t\t\t\t<a href="#" class="cdx-butt'
#  b'on cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weig'
#  b'ht-quiet cdx-button--icon-only" id="ca-talk-sticky-header" tabindex="-1" dat'
#  b'a-event-name="talk-sticky-header"><span class="vector-icon mw-ui-icon-speech'
#  b'Bubbles mw-ui-icon-wikimedia-speechBubbles"></span>\n\n<span></span>\n\t'
#  b'\t\t</a>\n\t\t\t<a href="#" class="cdx-button cdx-button--fake-button cdx-'
#  b'button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only"'
#  b' id="ca-subject-sticky-header" tabindex="-1" data-event-name="subject-sticky'
#  b'-header"><span class="vector-icon mw-ui-icon-article mw-ui-icon-wikimedia-ar'
#  b'ticle"></span>\n\n<span></span>\n\t\t\t</a>\n\t\t\t<a href="#" class="cdx-'
#  b'button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--'
#  b'weight-quiet cdx-button--icon-only" id="ca-history-sticky-header" tabindex="'
#  b'-1" data-event-name="history-sticky-header"><span class="vector-icon mw-ui-i'
#  b'con-wikimedia-history mw-ui-icon-wikimedia-wikimedia-history"></span>\n\n<'
#  b'span></span>\n\t\t\t</a>\n\t\t\t<a href="#" class="cdx-button cdx-button--fa'
#  b'ke-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-butt'
#  b'on--icon-only mw-watchlink" id="ca-watchstar-sticky-header" tabindex="-1" da'
#  b'ta-event-name="watch-sticky-header"><span class="vector-icon mw-ui-icon-wiki'
#  b'media-star mw-ui-icon-wikimedia-wikimedia-star"></span>\n\n<span></span>\n\t'
#  b'\t\t</a>\n\t\t\t<a href="#" class="cdx-button cdx-button--fake-button cdx-'
#  b'button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only '
#  b'reading-lists-bookmark" id="ca-bookmark-sticky-header" tabindex="-1" data-ev'
#  b'ent-name="watch-sticky-bookmark"><span class="vector-icon mw-ui-icon-wikimed'
#  b'ia-bookmarkOutline mw-ui-icon-wikimedia-wikimedia-bookmarkOutline"></spa'
#  b'n>\n\n<span></span>\n\t\t\t</a>\n\t\t\t<a href="#" class="cdx-button cdx-b'
#  b'utton--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet'
#  b' cdx-button--icon-only" id="ca-edit-sticky-header" tabindex="-1" data-event-'
#  b'name="wikitext-edit-sticky-header"><span class="vector-icon mw-ui-icon-wikim'
#  b'edia-wikiText mw-ui-icon-wikimedia-wikimedia-wikiText"></span>\n\n<span></'
#  b'span>\n\t\t\t</a>\n\t\t\t<a href="#" class="cdx-button cdx-button--fake-butt'
#  b'on cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--ico'
#  b'n-only" id="ca-ve-edit-sticky-header" tabindex="-1" data-event-name="ve-edit'
#  b'-sticky-header"><span class="vector-icon mw-ui-icon-wikimedia-edit mw-ui-ico'
#  b'n-wikimedia-wikimedia-edit"></span>\n\n<span></span>\n\t\t\t</a>\n\t\t\t<a'
#  b' href="#" class="cdx-button cdx-button--fake-button cdx-button--fake-button-'
#  b'-enabled cdx-button--weight-quiet cdx-button--icon-only" id="ca-viewsource-s'
#  b'ticky-header" tabindex="-1" data-event-name="ve-edit-protected-sticky-header'
#  b'"><span class="vector-icon mw-ui-icon-wikimedia-editLock mw-ui-icon-wikimedi'
#  b'a-wikimedia-editLock"></span>\n\n<span></span>\n\t\t\t</a>\n\t\t</div>\n\t\t'
#  b'\t<div class="vector-sticky-header-buttons">\n\t\t\t\t<button class="cdx-b'
#  b'utton cdx-button--weight-quiet mw-interlanguage-selector" id="p-lang-btn-sti'
#  b'cky-header" tabindex="-1" data-event-name="ui.dropdown-p-lang-btn-sticky-hea'
#  b'der"><span class="vector-icon mw-ui-icon-wikimedia-language mw-ui-icon-wikim'
#  b'edia-wikimedia-language"></span>\n\n<span>71 languages</span>\n\t\t\t</but'
#  b'ton>\n\t\t\t<a href="#" class="cdx-button cdx-button--fake-button cdx-button'
#  b'--fake-button--enabled cdx-button--weight-quiet cdx-button--action-progressi'
#  b've" id="ca-addsection-sticky-header" tabindex="-1" data-event-name="addsecti'
#  b'on-sticky-header"><span class="vector-icon mw-ui-icon-speechBubbleAdd-progre'
#  b'ssive mw-ui-icon-wikimedia-speechBubbleAdd-progressive"></span>\n\n<span>A'
#  b'dd topic</span>\n\t\t\t</a>\n\t\t</div>\n\t\t\t<div class="vector-sticky-he'
#  b'ader-icon-end">\n\t\t\t\t<div class="vector-user-links">\n\t\t\t\t</div>\n\t'
#  b'\t\t</div>\n\t\t</div>\n\t</div>\n</div>\n<div class="mw-portlet mw-portl'
#  b'et-dock-bottom emptyPortlet" id="p-dock-bottom">\n\t<ul>\n\t\t\n\t</ul>\n</d'
#  b'iv>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgHostn'
#  b'ame":"mw-web.codfw.main-7c6c4687f8-mq9lp","wgBackendResponseTime":190,"wgPag'
#  b'eParseReport":{"limitreport":{"cputime":"3.588","walltime":"3.859","ppvisite'
#  b'dnodes":{"value":33950,"limit":1000000},"revisionsize":{"value":124441,"limi'
#  b't":2097152},"postexpandincludesize":{"value":1100908,"limit":2097152},"templ'
#  b'ateargumentsize":{"value":11721,"limit":2097152},"expansiondepth":{"value":1'
#  b'2,"limit":100},"expensivefunctioncount":{"value":15,"limit":500},"unstrip-de'
#  b'pth":{"value":1,"limit":20},"unstrip-size":{"value":316944,"limit":5000000},'
#  b'"entityaccesscount":{"value":2,"limit":500},"timingprofile":["100.00% 2895.3'
#  b'75      1 -total"," 19.64%  568.681    732 Template:Convert"," 18.61%  538.9'
#  b'06    365 Template:Coord"," 12.39%  358.658    389 Template:Change","  6.54%'
#  b'  189.305      1 Template:Sister_project_links","  5.05%  146.236      1 Tem'
#  b'plate:Gallery","  4.41%  127.624      2 Template:Reflist","  3.89%  112.723 '
#  b'     2 Template:Location_map+","  3.81%  110.455      1 Template:Lang","  3.'
#  b'11%   89.941      1 Template:Short_description"]},"scribunto":{"limitreport-'
#  b'timeusage":{"value":"1.905","limit":"10.000"},"limitreport-memusage":{"value'
#  b'":20561045,"limit":52428800}},"cachereport":{"origin":"mw-web.codfw.main-7c6'
#  b'c4687f8-chtbr","timestamp":"20251013172641","ttl":2592000,"transientcontent"'
#  b':false}}});});</script>\n<script type="application/ld+json">{"@context":"'
#  b'https:\\/\\/schema.org","@type":"Article","name":"List of United States ci'
#  b'ties by population","url":"https:\\/\\/en.wikipedia.org\\/wiki\\/List_of_Uni'
#  b'ted_States_cities_by_population","sameAs":"http:\\/\\/www.wikidata.org\\/en'
#  b'tity\\/Q131079","mainEntity":"http:\\/\\/www.wikidata.org\\/entity\\/Q131'
#  b'079","author":{"@type":"Organization","name":"Contributors to Wikimedia proj'
#  b'ects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc'
#  b'.","logo":{"@type":"ImageObject","url":"https:\\/\\/www.wikimedia.org\\/sta'
#  b'tic\\/images\\/wmf-hor-googpub.png"}},"datePublished":"2005-03-26T00:07:17'
#  b'Z","dateModified":"2025-09-09T00:44:32Z","image":"https:\\/\\/upload.wikim'
#  b'edia.org\\/wikipedia\\/commons\\/7\\/7a\\/View_of_Empire_State_Building_f'
#  b'rom_Rockefeller_Center_New_York_City_dllu_%28cropped%29.jpg","headline":"Wik'
#  b'imedia list article"}</script>\n</body>\n</html>')

# %% [markdown]
# Use Beautiful Soup to parse this string into a tree called `soup`

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %% [markdown]
# To find an HTML tag corresponding to a specific element on a webpage, right-click on it and choose "Inspect element". Go to the cities table Wikipedia page and do this now.
#
# You should find that the cities table on the Wikipedia page corresponds to the element
#
# ```
# <table class="wikitable sortable jquery-tablesorter" style="text-align:center">
# ```

# %% [markdown]
# There are many `<table>` tags on the page.

# %%
len(soup.find_all("table"))
# Out:
# 10

# %%
pprint(soup.find_all("table"))
# Out:
# [<table class="sidebar nomobile nowraplinks"><tbody><tr><th class="sidebar-title">Population tables<br/>of U.S. cities</th></tr><tr><td class="sidebar-image"><span class="mw-default-size mw-image-border" typeof="mw:File/Frameless"><a class="mw-file-description" href="/wiki/File:View_of_Empire_State_Building_from_Rockefeller_Center_New_York_City_dllu_(cropped).jpg"><img alt="New York City skyline" class="mw-file-element" data-file-height="4616" data-file-width="8207" decoding="async" height="169" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7a/View_of_Empire_State_Building_from_Rockefeller_Center_New_York_City_dllu_%28cropped%29.jpg/330px-View_of_Empire_State_Building_from_Rockefeller_Center_New_York_City_dllu_%28cropped%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7a/View_of_Empire_State_Building_from_Rockefeller_Center_New_York_City_dllu_%28cropped%29.jpg/500px-View_of_Empire_State_Building_from_Rockefeller_Center_New_York_City_dllu_%28cropped%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7a/View_of_Empire_State_Building_from_Rockefeller_Center_New_York_City_dllu_%28cropped%29.jpg/960px-View_of_Empire_State_Building_from_Rockefeller_Center_New_York_City_dllu_%28cropped%29.jpg 2x" width="300"/></a></span><div class="sidebar-caption">The skyline of <a href="/wiki/New_York_City" title="New York City">New York City</a>, the most populous city in the <a href="/wiki/United_States" title="United States">United States</a></div></td></tr><tr><th class="sidebar-heading" style="background:lavender;">
# <a class="mw-selflink selflink">Cities</a></th></tr><tr><td class="sidebar-content">
# <span style="font-size:110%;"><a class="mw-selflink selflink">Population</a></span><div class="hlist"><ul><li><a href="/wiki/List_of_United_States_cities_by_area" title="List of United States cities by area">Area</a></li><li><a href="/wiki/List_of_United_States_cities_by_population_density" title="List of United States cities by population density">Density</a></li><li><a href="/wiki/Lists_of_United_States_cities_with_large_ethnic_minority_populations" title="Lists of United States cities with large ethnic minority populations">Ethnic identity</a></li><li><a href="/wiki/List_of_United_States_cities_by_foreign-born_population" title="List of United States cities by foreign-born population">Foreign-born</a></li><li><a href="/wiki/List_of_United_States_metropolitan_areas_by_per_capita_income" title="List of United States metropolitan areas by per capita income">Income</a></li><li><a href="/wiki/List_of_United_States_cities_by_Spanish-speaking_population" title="List of United States cities by Spanish-speaking population">Spanish speakers</a></li><li><a href="/wiki/List_of_capitals_in_the_United_States" title="List of capitals in the United States">Capitals</a></li><li><a href="/wiki/List_of_most_populous_cities_in_the_United_States_by_decade" title="List of most populous cities in the United States by decade">By decade</a></li><li><a href="/wiki/List_of_largest_cities_of_U.S._states_and_territories_by_population" title="List of largest cities of U.S. states and territories by population">By state</a></li><li><a href="/wiki/List_of_largest_cities_of_U.S._states_and_territories_by_historical_population" title="List of largest cities of U.S. states and territories by historical population">By decade/state</a></li></ul></div></td>
# </tr><tr><th class="sidebar-heading" style="background:lavender;">
# <a href="/wiki/List_of_United_States_urban_areas" title="List of United States urban areas">Urban areas</a></th></tr><tr><td class="sidebar-content">
# Populous cities and metropolitan areas</td>
# </tr><tr><th class="sidebar-heading" style="background:lavender;">
# <a href="/wiki/Statistical_area_(United_States)" title="Statistical area (United States)">Metropolitan areas</a></th></tr><tr><td class="sidebar-content">
# <div class="plainlist"><ul><li><a href="/wiki/Combined_statistical_area#List_of_combined_statistical_areas" title="Combined statistical area">184 combined statistical areas</a></li><li><a href="/wiki/List_of_core-based_statistical_areas" title="List of core-based statistical areas">935 core-based statistical areas</a></li><li><a class="mw-redirect" href="/wiki/List_of_metropolitan_statistical_areas" title="List of metropolitan statistical areas">393 metropolitan statistical areas</a></li><li><a class="mw-redirect" href="/wiki/List_of_micropolitan_statistical_areas" title="List of micropolitan statistical areas">542 micropolitan statistical areas</a></li></ul></div></td>
# </tr><tr><th class="sidebar-heading" style="background:lavender;">
# <a href="/wiki/Megaregions_of_the_United_States" title="Megaregions of the United States">Megaregions</a></th></tr><tr><td class="sidebar-below" style="background:lavender;line-height:1.3em;font-weight:normal; border-top:2px #fafafa solid;">
# <div class="plainlist"><ul><li><b>Related population lists</b></li><li><a href="/wiki/List_of_North_American_metropolitan_areas_by_population" title="List of North American metropolitan areas by population">North American metro areas</a></li><li><a class="mw-redirect" href="/wiki/List_of_cities_proper_by_population" title="List of cities proper by population">World cities</a></li><li><a href="/wiki/List_of_U.S._states_and_territories_by_population" title="List of U.S. states and territories by population">States and territories</a></li></ul></div></td></tr><tr><td class="sidebar-navbar"><link href="mw-data:TemplateStyles:r1129693374" rel="mw-deduplicated-inline-style"><style data-mw-deduplicate="TemplateStyles:r1239400231">.mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}html.skin-theme-clientpref-night .mw-parser-output .navbar li a abbr{color:var(--color-base)!important}@media(prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .navbar li a abbr{color:var(--color-base)!important}}@media print{.mw-parser-output .navbar{display:none!important}}</style><div class="navbar plainlinks hlist navbar-mini"><ul><li class="nv-view"><a href="/wiki/Template:U.S._city_population_tables" title="Template:U.S. city population tables"><abbr title="View this template">v</abbr></a></li><li class="nv-talk"><a href="/wiki/Template_talk:U.S._city_population_tables" title="Template talk:U.S. city population tables"><abbr title="Discuss this template">t</abbr></a></li><li class="nv-edit"><a href="/wiki/Special:EditPage/Template:U.S._city_population_tables" title="Special:EditPage/Template:U.S. city population tables"><abbr title="Edit this template">e</abbr></a></li></ul></div></link></td></tr></tbody></table>,
#  <table class="wikitable">
# <tbody><tr>
# <td style="background:#ffff99; width:1em">
# </td>
# <td><b>State capital</b>
# </td></tr>
# <tr>
# <td style="background:#cfecec; width:1em">
# </td>
# <td><i>State's largest city</i>
# </td></tr>
# <tr>
# <td style="background:#ccff99; width:1em">
# </td>
# <td><i><b>State capital and largest city</b></i>
# </td></tr>
# <tr>
# <td style="background:#ff9999; width:1em">
# </td>
# <td><i><b>Federal capital</b></i>
# </td></tr></tbody></table>,
#  <table class="sortable wikitable sticky-header-multi static-row-numbers sort-under col1left col2center" style="text-align:right">
# <tbody><tr>
# <th rowspan="2">City
# </th>
# <th rowspan="2"><abbr title="State or district">ST</abbr>
# </th>
# <th rowspan="2">2024<br/>estimate
# </th>
# <th rowspan="2">2020<br/>census
# </th>
# <th rowspan="2">Change
# </th>
# <th colspan="2">2020 land area
# </th>
# <th colspan="2">2020 density
# </th>
# <th rowspan="2">Location
# </th></tr>
# <tr class="static-row-header">
# <th>mi<sup>2</sup>
# </th>
# <th>km<sup>2</sup>
# </th>
# <th>/ mi<sup>2</sup>
# </th>
# <th>/ km<sup>2</sup>
# </th></tr>
# <tr>
# <td style="background-color:#cfecec"><i><a href="/wiki/New_York_City" title="New York City">New York</a></i><sup class="reference" id="cite_ref-5"><a href="#cite_note-5"><span class="cite-bracket">[</span>c<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a href="/wiki/New_York_(state)" title="New York (state)">NY</a>
# </td>
# <td style="text-align:right;">8,478,072
# </td>
# <td style="text-align:right;">8,804,190
# </td>
# <td style="text-align:right;"><span data-sort-value="2999630000000000000♠" style="display:none"></span><span style="color:red">−3.70%</span>
# </td>
# <td style="text-align:right;">300.5
# </td>
# <td style="text-align:right;">778.3
# </td>
# <td style="text-align:right;">29,298
# </td>
# <td style="text-align:right;">11,312
# </td>
# <td><small><span class="geo-inline"><style data-mw-deduplicate="TemplateStyles:r1156832818">.mw-parser-output .geo-default,.mw-parser-output .geo-dms,.mw-parser-output .geo-dec{display:inline}.mw-parser-output .geo-nondefault,.mw-parser-output .geo-multi-punct,.mw-parser-output .geo-inline-hidden{display:none}.mw-parser-output .longitude,.mw-parser-output .latitude{white-space:nowrap}</style><span class="plainlinks nourlexpansion"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params
# </td>
# <td><small><span class="geo-inline"><link href="mw-data:TemplateStyles:r1156832818" rel="mw-deduplicated-inline-style"/><span class="plainlinks nourlexpansion"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=35.21_N_80.83_W_&amp;title=Charlotte"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">35°13′N</span> <span class="longitude">80°50′W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">35.21°N 80.83°W</span><span style="display:none">﻿ / <span class="geo">35.21; -80.83</span></span><span style="display:none">﻿ (<span class="fn org">Charlotte</span>)</span></span></span></a></span></span></small>
# </td></tr>
# <tr>
# <td style="background-color:#ccff99"><i><b><a href="/wiki/Columbus,_Ohio" title="Columbus, Ohio">Columbus</a></b></i>
# </td>
# <td><a href="/wiki/Ohio" title="Ohio">OH</a>
# </td>
# <td style="text-align:right;">933,263
# </td>
# <td style="text-align:right;">905,748
# </td>
# <td style="text-align:right;"><span data-sort-value="7000304000000000000♠" style="display:none"></span><span style="color:green">+3.04%</span>
# </td>
# <td style="text-align:right;">220.0
# </td>
# <td style="text-align:right;">569.8
# </td>
# <td style="text-align:right;">4,117
# </td>
# <td style="text-align:right;">1,590
# </td>
# <td><small><span class="geo-inline"><link href="mw-data:TemplateStyles:r1156832818" rel="mw-deduplicated-inline-style"/><span class="plainlinks nourlexpansion"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=39.99_N_82.99_W_&amp;title=Columbus"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">39°59′N</span> <span class="longitude">82°59′W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">39.99°N 82.99°W</span><span style="display:none">﻿ / <span class="geo">39.99; -82.99</span></span><span style="display:none">﻿ (<span class="fn org">Columbus</span>)</span></span></span></a></span></span></small>
# </td></tr>
# <tr>
# <td style="background-color:#ccff99"><i><b><a href="/wiki/Indianapolis" title="Indianapolis">Indianapolis</a></b></i><sup class="reference" id="cite_ref-8"><a href="#cite_note-8"><span class="cite-bracket">[</span>f<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a href="/wiki/Indiana" title="Indiana">IN</a>
# </td>
# <td style="text-align:right;">891,484
# </td>
# <td style="text-align:right;">887,642
# </td>
# <td style="text-align:right;"><span data-sort-value="6999430000000000000♠" style="display:none"></span><span style="color:green">+0.43%</span>
# </td>
# <td style="text-align:right;">361.6
# </td>
# <td style="text-align:right;">936.5
# </td>
# <td style="text-align:right;">2,455
# </td>
# <td style="text-align:right;">948
# </td>
# <td><small><span class="geo-inline"><link href="mw-data:TemplateStyles:r1156832818" rel="mw-deduplicated-inline-style"/><span class="plainlinks nourlexpansion"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=39.78_N_86.15_W_&amp;title=Indianapolis"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">39°47′N</span> <span class="longitude">86°09′W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">39.78°N 86.15°W</span><span style="display:none">﻿ / <span class="geo">39.78; -86.15</span></span><span style="display:none">﻿ (<span class="fn org">Indianapolis</span>)</span></span></span></a></span></span></small>
# </td></tr>
# <tr>
# <td><a href="/wiki/San_Francisco" title="San Francisco">San Francisco</a><sup class="reference" id="cite_ref-9"><a href="#cite_note-9"><span class="cite-bracket">[</span>g<span class="cite-bracket">]</span></a></sup>
# </td>
# <td><a href="/wiki/California" title="California">CA</a>
# </td>
# <td style="text-align:right;">827,526
# </td>
# <td style="text-align:right;">873,965
# </td>
# <td style="text-align:right;"><span data-sort-value="2999469000000000000♠" style="display:none"></span><span style="color:red">−5.31%</span>
# </td>
# <td style="text-align:right;">46.9
# </td>
# <td style="text-align:right;">121.5
# </td>
# <td style="text-align:right;">18,635
# </td>
# <td style="text-align:right;">7,195
# </td>
# <td><small><span class="geo-inline"><link href="mw-data:TemplateStyles:r1156832818" rel="mw-deduplicated-inline-style"/><span class="plainlinks nourlexpansion"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=37.73_N_123.03_W_&amp;title=San+Francisco"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">37°44′N</span> <span class="longitude">123°02′W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">37.73°N 123.03°W</span><span style="display:none">﻿ / <span class="geo">37.73; -123.03</span></span><span style="display:none">﻿ (<span class="fn org">San Francisco</span>)</span></span></span></a></span></span></small>
# </td></tr>
# <tr>
# <td style="background-color:#cfecec"><i><a href="/wiki/Seattle" title="Seattle">Seattle</a></i>
# </td>
# <td><a href="/wiki/Washington_(state)" title="Washington (state)">WA</a>
# </td>
# <td style="text-align:right;">780,995
# </td>
# <td style="text-align:right;">737,015
# </td>
# <td style="text-align:right;"><span data-sort-value="7000597000000000000♠" style="display:none"></span><span style="color:green">+5.97%</span>
# </td>
# <td style="text-align:right;">83.8
# </td>
# <td style="text-align:right;">217.0
# </td>
# <td style="text-align:right;">8,795
# </td>
# <td style="text-align:right;">3,396
# </td>
# <td><small><span class="geo-inline"><link href="mw-data:TemplateStyles:r1156832818" rel="mw-deduplicated-inline-style"/><span class="plainlinks nourlexpansion"><a class="external text" href="https://geohack.toolforge.org/geohack.php?pagename=List_of_United_States_cities_by_population&amp;params=47.62_N_122.35_W_&amp;title=Seattle"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">47°37′N</span> <span class="longitude">122°21′W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="vcard"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">47.62°N 122.35°W</span><span style="display:none">﻿ / <span class="geo">47.62; -122.35</span></span><span style="display:none">﻿ (<span class="fn org">Seattle</span>)</span></span></span></a></span></span></small>
# </td></tr>
# <tr>
# <td style="background-color:#ccff99"><i><b><a href="/wiki/
                      "style": "text-align:right"}
                  )[0]

# %% [markdown]
# **Now you will write code to scrape the information in `table` to create a Pandas data frame with one row for each city and columns for: city, state, population (2022 estimate), and 2020 land area (sq mi).** Refer to the Notes/suggestions below as you write your code. A few Hints are provided further down, but try coding first before looking at the hints.

# %% [markdown]
# Notes/suggestions:
#
# - Use as a guide the code from the reading that produced the data frame of Statistics faculty
# - Inspect the page source as you write your code
# - You will need to write a loop to get the information for all cities, but you might want to try just scraping the info for New York first
# - You will need to pull the text from the tag. If `.text` returns text with "\n" at the end, try `.get_text(strip = True)` instead of `.text`
# - Don't forget to convert to a Pandas Data Frame; it should have 333 rows and 4 columns
# - The goal of this exercise is just to create the Data Frame. If you were going to use it --- e.g., what is the population density for all cities in CA? --- then you would need to clean the data first (to clean strings and convert to quantitative). (You can use Beautiful Soup to do some of the cleaning for you, but that goes beyond our scope.)

# %%
def clean_cell(tag):
    for sup in tag.find_all("sup"):
        sup.decompose()
    return tag.get_text(strip=True)

# %%
rows = []
for tr in table.find_all("tr")[1:]:          
    tds = tr.find_all("td")
    if len(tds) < 6:                          
        continue

    # After the rank <th>, the <td> order is:
    # 0 City | 1 State | 2 2022 estimate | 3 2020 census | 4 Change | 5 2020 land area (sq mi) | ...
    city  = clean_cell(tds[0])
    state = clean_cell(tds[1])
    pop22 = clean_cell(tds[2])
    area  = clean_cell(tds[5])

    rows.append({
        "city": city,
        "state": state,
        "population_2022_estimate": pop22,
        "land_area_sq_mi": area
    })

# %%
rows
# Out:
# [{'city': 'Allegheny',
#   'state': 'PA',
#   'population_2022_estimate': 'NA',
#   'land_area_sq_mi': '1907'},
#  {'city': 'Brooklyn',
#   'state': 'NY',
#   'population_2022_estimate': 'NA',
#   'land_area_sq_mi': '1898'},
#  {'city': 'Camden',
#   'state': 'NJ',
#   'population_2022_estimate': '71,749',
#   'land_area_sq_mi': '1950'},
#  {'city': 'Canton',
#   'state': 'OH',
#   'population_2022_estimate': '69,211',
#   'land_area_sq_mi': '1950'},
#  {'city': 'Citrus Heights',
#   'state': 'CA',
#   'population_2022_estimate': '86,909',
#   'land_area_sq_mi': '1990'},
#  {'city': 'Duluth',
#   'state': 'MN',
#   'population_2022_estimate': '87,986',
#   'land_area_sq_mi': '1960'},
#  {'city': 'Erie',
#   'state': 'PA',
#   'population_2022_estimate': '92,940',
#   'land_area_sq_mi': '1960'},
#  {'city': 'Fall River',
#   'state': 'MA',
#   'population_2022_estimate': '94,689',
#   'land_area_sq_mi': '1920'},
#  {'city': 'Flint',
#   'state': 'MI',
#   'population_2022_estimate': '79,735',
#   'land_area_sq_mi': '1960'},
#  {'city': 'Gary',
#   'state': 'IN',
#   'population_2022_estimate': '67,555',
#   'land_area_sq_mi': '1960'},
#  {'city': 'Hammond',
#   'state': 'IN',
#   'population_2022_estimate': '76,030',
#   'land_area_sq_mi': '1960'},
#  {'city': 'Livonia',
#   'state': 'MI',
#   'population_2022_estimate': '93,113',
#   'land_area_sq_mi': '1970'},
#  {'city': 'Niagara Falls',
#   'state': 'NY',
#   'population_2022_estimate': '47,512',
#   'land_area_sq_mi': '1960'},
#  {'city': 'Norwalk',
#   'state': 'CA',
#   'population_2022_estimate': '98,230',
#   'land_area_sq_mi': '2010'},
#  {'city': 'Parma',
#   'state': 'OH',
#   'population_2022_estimate': '79,350',
#   'land_area_sq_mi': '1970'},
#  {'city': 'Portsmouth',
#   'state': 'VA',
#   'population_2022_estimate': '96,482',
#   'land_area_sq_mi': '1960'},
#  {'city': 'Reading',
#   'state': 'PA',
#   'population_2022_estimate': '96,000',
#   'land_area_sq_mi': '1930'},
#  {'city': 'Roanoke',
#   'state': 'VA',
#   'population_2022_estimate': '97,912',
#   'land_area_sq_mi': '1980'},
#  {'city': 'Scranton',
#   'state': 'PA',
#   'population_2022_estimate': '75,905',
#   'land_area_sq_mi': '1930'},
#  {'city': 'Somerville',
#   'state': 'MA',
#   'population_2022_estimate': '82,149',
#   'land_area_sq_mi': '1930'},
#  {'city': 'St. Joseph',
#   'state': 'MO',
#   'population_2022_estimate': '71,098',
#   'land_area_sq_mi': '1900'},
#  {'city': 'Trenton',
#   'state': 'NJ',
#   'population_2022_estimate': '91,193',
#   'land_area_sq_mi': '1950'},
#  {'city': 'Utica',
#   'state': 'NY',
#   'population_2022_estimate': '63,660',
#   'land_area_sq_mi': '1930'},
#  {'city': 'Wilmington',
#   'state': 'DE',
#   'population_2022_estimate': '73,176',
#   'land_area_sq_mi': '1940'},
#  {'city': 'Youngstown',
#   'state': 'OH',
#   'population_2022_estimate': '59,123',
#   'land_area_sq_mi': '1930'}]

# %%
df_cities = pd.DataFrame(rows)
df_cities.shape, df_cities.head()
# Out:
# ((25, 4),
#               city state population_2022_estimate land_area_sq_mi
#  0       Allegheny    PA                       NA            1907
#  1        Brooklyn    NY                       NA            1898
#  2          Camden    NJ                   71,749            1950
#  3          Canton    OH                   69,211            1950
#  4  Citrus Heights    CA                   86,909            1990)

# %% [markdown]
# Hints:
#
# - Each city is a row in the table; find all the `<tr>` tags to find all the cities
# - Look for the `<td>` tag to see table entries within a row
# - The rank column is represented by `<th>` tags, rather than `<td>` tags. So within a row, the first (that is, `[0]`) `<td>` tag corresponds to the city name.

# %% [markdown]
# ## Aside: Scraping an HTML table with Pandas

# %% [markdown]
# The Pandas command `read_html` can be used to scrape information from an HTML table on a webpage.
#
# We can call `read_html` on the URL.

# %%
pd.read_html("https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population")

# %% [markdown]
# However, this scrapes all the tables on the webpage, not just the one we want. As with Beautiful Soup, we can narrow the search by specifying the table attributes.

# %%
pd.read_html("https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population", attrs = {'class': 'wikitable sortable', "style": "text-align:center"})

# %% [markdown]
# This still returns 3 tables. As we remarked above, the table that we want is the first one (see `[0]` below).

# %%
df_cities2 = pd.read_html("https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population", attrs = {'class': 'wikitable sortable', "style": "text-align:center"})[0]
df_cities2

# %% [markdown]
# Wait, that seemed much easier than using Beautiful Soup, and it returned a data frame, and we even got for free some formatting like removing the commas from the population! Why didn't we just use `read_html` in the first place? It's true the `read_html` works well when scraping information from an HTML *table*. Unfortunately, you often want to scrape information from a webpage that isn't conveniently stored in an HTML table, in which case `read_html` won't work. (It only searches for `<table>`, `<th>`, `<tr>`, and `<td>` tags, but there are many other HTML tags.) Though Beautiful Soup is not as simple as `read_html`, it is more flexible and thus more widely applicable.

# %% [markdown]
# ## Scraping information that is NOT in a `<table>` with Beautiful Soup

# %% [markdown]
# The Cal Poly course catalog http://catalog.calpoly.edu/collegesandprograms/collegeofsciencemathematics/statistics/#courseinventory contains a list of courses offered by the Statistics department. **You will scrape this website to obtain a Pandas data frame with one row for each DATA or STAT course and two columns: course name and number (e.g, DATA 301. Introduction to Data Science) and term typically offered (e.g., Term Typically Offered: F, W, SP).**

# %% [markdown]
# Note: Pandas `read_html` is not help here since the courses are not stored in a `<table>.`

# %%
pd.read_html("http://catalog.calpoly.edu/collegesandprograms/collegeofsciencemathematics/statistics/#courseinventory")

# %% [markdown]
# Notes/suggestions:
#
#
# - Inspect the page source as you write your code
# - The courses are not stored in a `<table>`. How are they stored?
# - You will need to write a loop to get the information for all courses, but you might want to try just scraping the info for DATA 100 first
# - What kind of tag is the course name stored in? What is the `class` of the tag?
# - What kind of tag is the quarter(s) the course is offered stored in? What is the `class` of the tag? Is this the only tag of this type with the class? How will you get the one you want?
# - You don't have to remove the number of units (e.g., 4 units) from the course name and number, but you can try it if you want
# - You will need to pull the text from the tag. If `.text` returns text with "\n" at the end, try `get_text(strip = True)` instead of `text`
# - Don't forget to convert to a Pandas Data Frame; it should have 74 rows and 2 columns
# - The goal of this exercise is just to create the Data Frame. If you were going to use it then you might need to clean the data first. (You can use Beautiful Soup to do some of the cleaning for you, but that goes beyond our scope.)

# %%
CATALOG_URL = "http://catalog.calpoly.edu/collegesandprograms/collegeofsciencemathematics/statistics/#courseinventory"
HEADERS = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}

resp = requests.get(CATALOG_URL, headers=HEADERS)
soup = BeautifulSoup(resp.content, "html.parser")

# %%
courses = []
for block in soup.find_all("div", {"class": "courseblock"}):
    title_tag = block.find("p", {"class": "courseblocktitle"})
    if not title_tag:
        continue

    title_text = title_tag.get_text(" ", strip=True)
    if not (title_text.startswith("STAT") or title_text.startswith("DATA")):
        continue

    # remove "(X units)" span if present
    for span in title_tag.find_all("span"):
        span.extract()
    course_name = title_tag.get_text(" ", strip=True)

    # first noindent line is typically "Term Typically Offered: ..."
    term_tag = block.find("p", {"class": "noindent"})
    term_text = term_tag.get_text(" ", strip=True) if term_tag else ""

    # if not the right line, search all noindent p's for the one that starts with it
    if not term_text.lower().startswith("term typically offered"):
        for p in block.find_all("p", {"class": "noindent"}):
            t = p.get_text(" ", strip=True)
            if t.lower().startswith("term typically offered"):
                term_text = t
                break

    courses.append({"course": course_name, "term_typically_offered": term_text})

# %%
df_courses = pd.DataFrame(courses)
df_courses.shape, df_courses.head()
# Out:
# ((74, 2),
#                                                course  \
#  0                  DATA 100. Data Science for All I.
#  1            DATA 301. Introduction to Data Science.
#  2         DATA 401. Data Science Process and Ethics.
#  3  DATA 402. Mathematical Foundations of Data Sci...
#  4        DATA 403. Data Science Projects Laboratory.
#
#               term_typically_offered
#  0  Term Typically Offered: F, W, SP
#  1  Term Typically Offered: F, W, SP
#  2         Term Typically Offered: F
#  3         Term Typically Offered: F
#  4         Term Typically Offered: F  )

# %% [markdown]
# Hints:
#
# - Each course is represented by a `<div>` with `class=courseblock`, so you can find all the courses with `soup.find_all("div", {"class": "courseblock"})`
# - The course name is in a `<p>` tag with `class=courseblocktitle`, inside a `<strong>` tag. (Though I don't think we need to find the strong tag here.)
# - The term typically offered is in `<p>` tag with `class=noindent`. However, there are several tags with this class; term typically offered is the first one.
# - If you want to use Beautiful Soup to remove the course units (e.g., 4 units), find the `<span>` tag within the course name tag and `.extract()` this span tag
